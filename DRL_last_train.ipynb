# %%
#!pip install --upgrade gym

# %%
import os
import gc
import torch
import pygame
import warnings
import numpy as np
import torch.nn as nn
import gymnasium as gym
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
from gym.wrappers import RecordVideo

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

gc.collect()
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1' # Used for debugging; CUDA related errors shown immediately.

# Seed everything for reproducible results
seed = 2024
np.random.seed(seed)
np.random.default_rng(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


class ReplayMemory:
    def __init__(self, capacity):
        """
        Experience Replay Memory defined by deques to store transitions/agent experiences
        """

        self.capacity = capacity

        self.states       = deque(maxlen=capacity)
        self.actions      = deque(maxlen=capacity)
        self.next_states  = deque(maxlen=capacity)
        self.rewards      = deque(maxlen=capacity)
        self.dones        = deque(maxlen=capacity)


    def store(self, state, action, next_state, reward, done):
        """
        Append (store) the transitions to their respective deques
        """

        self.states.append(state)
        self.actions.append(action)
        self.next_states.append(next_state)
        self.rewards.append(reward)
        self.dones.append(done)


    def sample(self, batch_size):
        """
        Randomly sample transitions from memory, then convert sampled transitions
        to tensors and move to device (CPU or GPU).
        """

        indices = np.random.choice(len(self), size=batch_size, replace=False)

        states = torch.stack([torch.as_tensor(self.states[i], dtype=torch.float32, device=device) for i in indices]).to(device)
        actions = torch.as_tensor([self.actions[i] for i in indices], dtype=torch.long, device=device)
        next_states = torch.stack([torch.as_tensor(self.next_states[i], dtype=torch.float32, device=device) for i in indices]).to(device)
        rewards = torch.as_tensor([self.rewards[i] for i in indices], dtype=torch.float32, device=device)
        dones = torch.as_tensor([self.dones[i] for i in indices], dtype=torch.bool, device=device)

        return states, actions, next_states, rewards, dones


    def __len__(self):
        """
        To check how many samples are stored in the memory. self.dones deque
        represents the length of the entire memory.
        """

        return len(self.dones)


class DQN_Network(nn.Module):
    """
    The Deep Q-Network (DQN) model for reinforcement learning.
    This network consists of Fully Connected (FC) layers with ReLU activation functions.
    """

    def __init__(self, num_actions, input_dim):
        """
        Initialize the DQN network.

        Parameters:
            num_actions (int): The number of possible actions in the environment.
            input_dim (int): The dimensionality of the input state space.
        """

        super(DQN_Network, self).__init__()

        self.FC = nn.Sequential(
            nn.Linear(input_dim, 12),
            nn.ReLU(inplace=True),
            nn.Linear(12, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, num_actions)
            )

        # Initialize FC layer weights using He initialization
        for layer in [self.FC]:
            for module in layer:
                if isinstance(module, nn.Linear):
                    nn.init.kaiming_uniform_(module.weight, nonlinearity='relu')


    def forward(self, x):
        """
        Forward pass of the network to find the Q-values of the actions.

        Parameters:
            x (torch.Tensor): Input tensor representing the state.

        Returns:
            Q (torch.Tensor): Tensor containing Q-values for each action.
        """

        Q = self.FC(x)
        return Q


class DQN_Agent:
    """
    DQN Agent Class. This class defines some key elements of the DQN algorithm,
    such as the learning method, hard update, and action selection based on the
    Q-value of actions or the epsilon-greedy policy.
    """

    def __init__(self, env, epsilon_max, epsilon_min, epsilon_decay,
                  clip_grad_norm, learning_rate, discount, memory_capacity):

        # To save the history of network loss
        self.loss_history = []
        self.running_loss = 0
        self.learned_counts = 0

        # RL hyperparameters
        self.epsilon_max   = epsilon_max
        self.epsilon_min   = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.discount      = discount

        self.action_space  = env.action_space
        self.action_space.seed(seed) # Set the seed to get reproducible results when sampling the action space
        self.observation_space = env.observation_space
        self.replay_memory = ReplayMemory(memory_capacity)

        # Initiate the network models
        input_dim = self.observation_space.shape[0]
        output_dim = self.action_space.n

        self.main_network = DQN_Network(num_actions=output_dim, input_dim=input_dim).to(device)
        self.target_network = DQN_Network(num_actions=output_dim, input_dim=input_dim).to(device).eval()
        self.target_network.load_state_dict(self.main_network.state_dict())

        self.clip_grad_norm = clip_grad_norm # For clipping exploding gradients caused by high reward value
        self.critertion = nn.MSELoss()
        self.optimizer = optim.Adam(self.main_network.parameters(), lr=learning_rate)


    def select_action(self, state):
        """
        Selects an action using epsilon-greedy strategy OR based on the Q-values.

        Parameters:
            state (torch.Tensor): Input tensor representing the state.

        Returns:
            action (int): The selected action.
        """

        # Exploration: epsilon-greedy
        if np.random.random() < self.epsilon_max:
            return self.action_space.sample()

        # Exploitation: the action is selected based on the Q-values.
        # Check if the state is a tensor or not. If not, make it a tensor
        if not torch.is_tensor(state):
            state = torch.as_tensor(state, dtype=torch.float32, device=device)

        with torch.no_grad():
            Q_values = self.main_network(state)
            action = torch.argmax(Q_values).item()

            return action


    def learn(self, batch_size, done):
        """
        Train the main network using a batch of experiences sampled from the replay memory.

        Parameters:
            batch_size (int): The number of experiences to sample from the replay memory.
            done (bool): Indicates whether the episode is done or not. If done,
            calculate the loss of the episode and append it in a list for plot.
        """

        # Sample a batch of experiences from the replay memory
        states, actions, next_states, rewards, dones = self.replay_memory.sample(batch_size)


        # # The following prints are for debugging. Use them to indicate the correct shape of the tensors.
        # print('Before--------Before')
        # print("states:", states.shape)
        # print("actions:", actions.shape)
        # print("next_states:", next_states.shape)
        # print("rewards:", rewards.shape)
        # print("dones:", dones.shape)


        # # Preprocess the data for training
        # states        = states.unsqueeze(1)
        # next_states   = next_states.unsqueeze(1)
        actions       = actions.unsqueeze(1)
        rewards       = rewards.unsqueeze(1)
        dones         = dones.unsqueeze(1)


        # # The following prints are for debugging. Use them to indicate the correct shape of the tensors.
        # print()
        # print('After--------After')
        # print("states:", states.shape)
        # print("actions:", actions.shape)
        # print("next_states:", next_states.shape)
        # print("rewards:", rewards.shape)
        # print("dones:", dones.shape)


        predicted_q = self.main_network(states) # forward pass through the main network to find the Q-values of the states
        predicted_q = predicted_q.gather(dim=1, index=actions) # selecting the Q-values of the actions that were actually taken

        # Compute the maximum Q-value for the next states using the target network
        with torch.no_grad():
            next_target_q_value = self.target_network(next_states).max(dim=1, keepdim=True)[0] # not argmax (cause we want the maxmimum q-value, not the action that maximize it)


        next_target_q_value[dones] = 0 # Set the Q-value for terminal states to zero
        y_js = rewards + (self.discount * next_target_q_value) # Compute the target Q-values
        loss = self.critertion(predicted_q, y_js) # Compute the loss

        # Update the running loss and learned counts for logging and plotting
        self.running_loss += loss.item()
        self.learned_counts += 1

        if done:
            episode_loss = self.running_loss / self.learned_counts # The average loss for the episode
            self.loss_history.append(episode_loss) # Append the episode loss to the loss history for plotting
            # Reset the running loss and learned counts
            self.running_loss = 0
            self.learned_counts = 0

        self.optimizer.zero_grad() # Zero the gradients
        loss.backward() # Perform backward pass and update the gradients

        # # Uncomment the following two lines to find the best value for clipping gradient (Comment torch.nn.utils.clip_grad_norm_ while uncommenting the following two lines)
        # grad_norm_before_clip = torch.nn.utils.clip_grad_norm_(self.main_network.parameters(), float('inf'))
        # print("Gradient norm before clipping:", grad_norm_before_clip)

        # Clip the gradients to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(self.main_network.parameters(), self.clip_grad_norm)

        self.optimizer.step() # Update the parameters of the main network using the optimizer


    def hard_update(self):
        """
        Navie update: Update the target network parameters by directly copying
        the parameters from the main network.
        """

        self.target_network.load_state_dict(self.main_network.state_dict())


    def update_epsilon(self):
        """
        Update the value of epsilon for epsilon-greedy exploration.

        This method decreases epsilon over time according to a decay factor, ensuring
        that the agent becomes less exploratory and more exploitative as training progresses.
        """

        self.epsilon_max = max(self.epsilon_min, self.epsilon_max * self.epsilon_decay)


    def save(self, path):
        """
        Save the parameters of the main network to a file with .pth extention.

        """
        torch.save(self.main_network.state_dict(), path)


class step_wrapper(gym.Wrapper):
    """
    A wrapper class for modifying the state and reward functions of the
    MountainCar-v0 environment.
    """

    def __init__(self, env):
        """
        Initializes the StepWrapper. This is the main class for wrapping the environment with it.

        Args:
            env (gym.Env): The environment to be wrapped.

        Attributes:
            observation_wrapper (Inherit from ObservationWrapper):
                An instance of the ObservationWrapper class for modifying observations.
            reward_wrapper (Inherit from RewardWrapper):
                An instance of the RewardWrapper class for modifying rewards.
        """
        super().__init__(env) # We give the env here to initialize the gym.Wrapper superclass (inherited).

        self.observation_wrapper = observation_wrapper(env)
        self.reward_wrapper = reward_wrapper(env)


    def step(self, action):
        """
        Executes a step in the environment with the provided action.The reason
        behind using this method is to have access to the state and reward functions return.

        Args:
            action (int): The action to be taken.
        """

        state, reward, done, truncation, info = self.env.step(action) # Same as before as usual

        modified_state = self.observation_wrapper.observation(state) # Give the state to another Wrapper, which returns a modified version of state
        modified_reward = self.reward_wrapper.reward(modified_state) # Give the modified state to another Wrapper to return the modified reward

        return modified_state, modified_reward, done, truncation, info # The same returns as usual but with modified versions of the state and reward functions


    def reset(self, seed):
        state, info = self.env.reset(seed=seed) # Same as before as usual
        modified_state = self.observation_wrapper.observation(state) # Give the state to another Wrapper, which returns a modified version of state

        return modified_state, info # Same as before as usual but with returning the modified version of the state


class observation_wrapper(gym.ObservationWrapper):
    """
    Wrapper class for modifying observations in the MountainCar-v0 environment.

    Args:
        env (gym.Env): The environment to wrap.

    Attributes:
        min_value (numpy.ndarray): Array of minimum observation values (2 dimensions because of the state.).
        max_value (numpy.ndarray): Array of maximum observation values (2 dimensions because of the state.).
    """

    def __init__(self, env):
        super().__init__(env)

        self.min_value = env.observation_space.low
        self.max_value = env.observation_space.high


    def observation(self, state):
        """
        Modifies the observation by clipping the values and normalizing it.

        Args:
            state (numpy.ndarray): The original observation from the environment.

        Returns:
            numpy.ndarray: The modified and normalized observation.
        """

        normalized_state = (state - self.min_value) / (self.max_value - self.min_value) # Min-max normalization

        return normalized_state


class reward_wrapper(gym.RewardWrapper):
    """
    Wrapper class for modifying rewards in the MountainCar-v0 environment.

    Args:
        env (gym.Env): The environment to wrap.
    """

    def __init__(self, env):
        super().__init__(env)


    def reward(self, state):
        """
        Modifies the reward based on the current state of the environment.

        Args:
            state (numpy.ndarray): The current state of the environment.

        Returns:
            float: The modified reward.
        """

        current_position, current_velocity = state # extract the position and current velocity based on the state

        # Interpolate the value to the desired range (because the velocity normalized value would be in range of 0 to 1 and now it would be in range of -0.5 to 0.5)
        current_velocity = np.interp(current_velocity, np.array([0, 1]), np.array([-0.5, 0.5]))

        # (1) Calculate the modified reward based on the current position and velocity of the car.
        degree = current_position * 360
        degree2radian = np.deg2rad(degree)
        modified_reward =  0.2 * (np.cos(degree2radian) + 2 * np.abs(current_velocity))

        # (2) Step limitation
        modified_reward -= 0.5 # Subtract 0.5 to adjust the base reward (to limit useless steps).

        # (3) Check if the car has surpassed a threshold of the path and is closer to the goal
        if current_position > 0.98:
            modified_reward += 20  # Add a bonus reward (Reached the goal)
        elif current_position > 0.92:
            modified_reward += 10 # So close to the goal
        elif current_position > 0.82:
            modified_reward += 6 # car is closer to the goal
        elif current_position > 0.65:
            modified_reward += 1 - np.exp(-2 * current_position) # car is getting close. Thus, giving reward based on the position and the further it reached


        # (4) Check if the car is coming down with velocity from left and goes with full velocity to right
        initial_position = 0.40842572 # Normalized value of initial position of the car which is extracted manually

        if current_velocity > 0.3 and current_position > initial_position + 0.1:
            modified_reward += 1 + 2 * current_position  # Add a bonus reward for this desired behavior

        return modified_reward

# %%
class Model_TrainTest():
    def __init__(self, hyperparams):

        # Define RL Hyperparameters
        self.train_mode             = hyperparams["train_mode"]
        self.RL_load_path           = hyperparams["RL_load_path"]
        self.save_path              = hyperparams["save_path"]
        self.save_interval          = hyperparams["save_interval"]

        self.clip_grad_norm         = hyperparams["clip_grad_norm"]
        self.learning_rate          = hyperparams["learning_rate"]
        self.discount_factor        = hyperparams["discount_factor"]
        self.batch_size             = hyperparams["batch_size"]
        self.update_frequency       = hyperparams["update_frequency"]
        self.max_episodes           = hyperparams["max_episodes"]
        self.max_steps              = hyperparams["max_steps"]
        self.render                 = hyperparams["render"]

        self.epsilon_max            = hyperparams["epsilon_max"]
        self.epsilon_min            = hyperparams["epsilon_min"]
        self.epsilon_decay          = hyperparams["epsilon_decay"]

        self.memory_capacity        = hyperparams["memory_capacity"]

        self.render_fps             = hyperparams["render_fps"]

        # Define Env
        self.env = gym.make('MountainCar-v0', max_episode_steps=self.max_steps,
                            render_mode="rgb_array_list" if self.render else None)
        self.env.metadata['render_fps'] = self.render_fps # For max frame rate make it 0

        """
        The 'MountainCar-v0' environment in the 'gymnasium' library generates
        UserWarnings about deprecated methods.
        These warnings are related to the 'size' and 'shape' methods which are
        being phased out in a future version of the library.
        Even though we are not directly using these methods in our code, the
        warnings are still displayed.
        To keep our output clean and focused on our own program's execution,
        the following line of code is for ignoring these warnings.
        """
        warnings.filterwarnings("ignore", category=UserWarning)

        # Apply RewardWrapper
        self.env = step_wrapper(self.env)

        # Define the agent class
        self.agent = DQN_Agent(env               = self.env,
                               epsilon_max       = self.epsilon_max,
                               epsilon_min       = self.epsilon_min,
                               epsilon_decay     = self.epsilon_decay,
                               clip_grad_norm    = self.clip_grad_norm,
                               learning_rate     = self.learning_rate,
                               discount          = self.discount_factor,
                               memory_capacity   = self.memory_capacity)


    def train(self):
        """
        Reinforcement learning training loop.
        """

        total_steps = 0
        self.reward_history = []

        # Training loop over episodes
        for episode in range(1, self.max_episodes+1):
            state, _ = self.env.reset(seed=seed)
            done = False
            truncation = False
            step_size = 0
            episode_reward = 0

            while not done and not truncation:
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)

                self.agent.replay_memory.store(state, action, next_state, reward, done)

                if len(self.agent.replay_memory) > self.batch_size:
                    self.agent.learn(self.batch_size, (done or truncation))

                    # Update target-network weights
                    if total_steps % self.update_frequency == 0:
                        self.agent.hard_update()

                state = next_state
                episode_reward += reward
                step_size +=1

            # Appends for tracking history
            self.reward_history.append(episode_reward) # episode reward
            total_steps += step_size

            # Decay epsilon at the end of each episode
            self.agent.update_epsilon()

            #-- based on interval
            if episode % self.save_interval == 0:
                self.agent.save(self.save_path + '_' + f'{episode}' + '.pth')
                if episode != self.max_episodes:
                    self.plot_training(episode)
                print('\n~~~~~~Interval Save: Model saved.\n')

            result = (f"Episode: {episode}, "
                      f"Total Steps: {total_steps}, "
                      f"Ep Step: {step_size}, "
                      f"Raw Reward: {episode_reward:.2f}, "
                      f"Epsilon: {self.agent.epsilon_max:.2f}")
            print(result)
        self.plot_training(episode)


    def test(self, max_episodes):
        """
        Reinforcement learning policy evaluation.
        """

        # Load the weights of the test_network
        self.agent.main_network.load_state_dict(torch.load(self.RL_load_path))
        self.agent.main_network.eval()
        history = []
        rewards=[]
        steps=[]
        failed =0
        # Testing loop over episodes
        for episode in range(1, max_episodes+1):
            frames = []
            state, _ = self.env.reset(seed=seed)
            done = False
            truncation = False
            step_size = 0
            episode_reward = 0
            temp_history= []
            while not done and not truncation:
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)

                state = next_state
                episode_reward += reward
                step_size += 1
                temp_history.append({'state':state,'action':action})
                frames.append(self.env.render())
            if step_size<200:
                history = history + temp_history
            if step_size>499:
                failed +=1
            # Print log
            steps.append(step_size)
            rewards.append(episode_reward)
            result = (f"Episode: {episode}, "
                      f"Steps: {step_size:}, "
                      f"Reward: {episode_reward:.2f}, ")
            print(result)

        pygame.quit() # close the rendering window
        return history,frames,steps,rewards,failed

    def plot_training(self, episode):
        # Calculate the Simple Moving Average (SMA) with a window size of 50
        sma = np.convolve(self.reward_history, np.ones(50)/50, mode='valid')

        # Clip max (high) values for better plot analysis
        reward_history = np.clip(self.reward_history, a_min=None, a_max=100)
        sma = np.clip(sma, a_min=None, a_max=100)

        plt.figure()
        plt.title("Obtained Rewards")
        plt.plot(reward_history, label='Raw Reward', color='#4BA754', alpha=1)
        plt.plot(sma, label='SMA 50', color='#F08100')
        plt.xlabel("Episode")
        plt.ylabel("Rewards")
        plt.legend()

        # Only save as file if last episode
        if episode == self.max_episodes:
            plt.savefig('./reward_plot.png', format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()


        plt.figure()
        plt.title("Network Loss")
        plt.plot(self.agent.loss_history, label='Loss', color='#8921BB', alpha=1)
        plt.xlabel("Episode")
        plt.ylabel("Loss")

        # Only save as file if last episode
        if episode == self.max_episodes:
            plt.savefig('./Loss_plot.png', format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()

# %%
train_mode = True
render = not train_mode
RL_hyperparams = {
    "train_mode"            : train_mode,
    "RL_load_path"          : './final_weights' + '_' + '1000' + '.pth',
    "save_path"             : './final_weights',
    "save_interval"         : 100,

    "clip_grad_norm"        : 5,
    "learning_rate"         : 75e-5,
    "discount_factor"       : 0.96,
    "batch_size"            : 64,
    "update_frequency"      : 20,
    "max_episodes"          : 1000           if train_mode else 2,
    "max_steps"             : 500,
    "render"                : render,

    "epsilon_max"           : 0.999         if train_mode else -1,
    "epsilon_min"           : 0.01,
    "epsilon_decay"         : 0.997,

    "memory_capacity"       : 125_000        if train_mode else 0,

    "render_fps"            : 60,
    }


# Run
DRL = Model_TrainTest(RL_hyperparams) # Define the instance
# Train
if train_mode:
    DRL.train()
else:
    # Test
    # history,frames = DRL.test(max_episodes = RL_hyperparams['max_episodes'])
    history,frames,steps,rewards,failed = DRL.test(max_episodes =50)
# Out:
# Episode: 1, Total Steps: 500, Ep Step: 500, Raw Reward: -303.85, Epsilon: 1.00
# Episode: 2, Total Steps: 1000, Ep Step: 500, Raw Reward: -294.35, Epsilon: 0.99
# Episode: 3, Total Steps: 1500, Ep Step: 500, Raw Reward: -314.98, Epsilon: 0.99
# Episode: 4, Total Steps: 2000, Ep Step: 500, Raw Reward: -284.38, Epsilon: 0.99
# Episode: 5, Total Steps: 2500, Ep Step: 500, Raw Reward: -314.81, Epsilon: 0.98
# Episode: 6, Total Steps: 3000, Ep Step: 500, Raw Reward: -307.78, Epsilon: 0.98
# Episode: 7, Total Steps: 3500, Ep Step: 500, Raw Reward: -304.71, Epsilon: 0.98
# Episode: 8, Total Steps: 4000, Ep Step: 500, Raw Reward: -301.16, Epsilon: 0.98
# Episode: 9, Total Steps: 4500, Ep Step: 500, Raw Reward: -314.22, Epsilon: 0.97
# Episode: 10, Total Steps: 5000, Ep Step: 500, Raw Reward: -309.49, Epsilon: 0.97
# Episode: 11, Total Steps: 5500, Ep Step: 500, Raw Reward: -305.82, Epsilon: 0.97
# Episode: 12, Total Steps: 6000, Ep Step: 500, Raw Reward: -299.91, Epsilon: 0.96
# Episode: 13, Total Steps: 6500, Ep Step: 500, Raw Reward: -302.99, Epsilon: 0.96
# Episode: 14, Total Steps: 7000, Ep Step: 500, Raw Reward: -294.33, Epsilon: 0.96
# Episode: 15, Total Steps: 7500, Ep Step: 500, Raw Reward: -302.13, Epsilon: 0.95
# Episode: 16, Total Steps: 8000, Ep Step: 500, Raw Reward: -281.61, Epsilon: 0.95
# Episode: 17, Total Steps: 8500, Ep Step: 500, Raw Reward: -290.29, Epsilon: 0.95
# Episode: 18, Total Steps: 9000, Ep Step: 500, Raw Reward: -294.13, Epsilon: 0.95
# Episode: 19, Total Steps: 9500, Ep Step: 500, Raw Reward: -302.43, Epsilon: 0.94
# Episode: 20, Total Steps: 10000, Ep Step: 500, Raw Reward: -314.06, Epsilon: 0.94
# Episode: 21, Total Steps: 10500, Ep Step: 500, Raw Reward: -302.78, Epsilon: 0.94
# Episode: 22, Total Steps: 11000, Ep Step: 500, Raw Reward: -294.21, Epsilon: 0.94
# Episode: 23, Total Steps: 11500, Ep Step: 500, Raw Reward: -309.78, Epsilon: 0.93
# Episode: 24, Total Steps: 12000, Ep Step: 500, Raw Reward: -298.48, Epsilon: 0.93
# Episode: 25, Total Steps: 12500, Ep Step: 500, Raw Reward: -281.58, Epsilon: 0.93
# Episode: 26, Total Steps: 13000, Ep Step: 500, Raw Reward: -307.56, Epsilon: 0.92
# Episode: 27, Total Steps: 13500, Ep Step: 500, Raw Reward: -308.68, Epsilon: 0.92
# Episode: 28, Total Steps: 14000, Ep Step: 500, Raw Reward: -297.19, Epsilon: 0.92
# Episode: 29, Total Steps: 14500, Ep Step: 500, Raw Reward: -285.44, Epsilon: 0.92
# Episode: 30, Total Steps: 15000, Ep Step: 500, Raw Reward: -305.03, Epsilon: 0.91
# Episode: 31, Total Steps: 15500, Ep Step: 500, Raw Reward: -304.82, Epsilon: 0.91
# Episode: 32, Total Steps: 16000, Ep Step: 500, Raw Reward: -304.87, Epsilon: 0.91
# Episode: 33, Total Steps: 16500, Ep Step: 500, Raw Reward: -308.75, Epsilon: 0.90
# Episode: 34, Total Steps: 17000, Ep Step: 500, Raw Reward: -266.94, Epsilon: 0.90
# Episode: 35, Total Steps: 17500, Ep Step: 500, Raw Reward: -298.98, Epsilon: 0.90
# Episode: 36, Total Steps: 18000, Ep Step: 500, Raw Reward: -300.02, Epsilon: 0.90
# Episode: 37, Total Steps: 18500, Ep Step: 500, Raw Reward: -307.46, Epsilon: 0.89
# Episode: 38, Total Steps: 19000, Ep Step: 500, Raw Reward: -284.93, Epsilon: 0.89
# Episode: 39, Total Steps: 19500, Ep Step: 500, Raw Reward: -304.16, Epsilon: 0.89
# Episode: 40, Total Steps: 20000, Ep Step: 500, Raw Reward: -291.60, Epsilon: 0.89
# Episode: 41, Total Steps: 20500, Ep Step: 500, Raw Reward: -309.86, Epsilon: 0.88
# Episode: 42, Total Steps: 21000, Ep Step: 500, Raw Reward: -299.94, Epsilon: 0.88
# Episode: 43, Total Steps: 21500, Ep Step: 500, Raw Reward: -302.39, Epsilon: 0.88
# Episode: 44, Total Steps: 22000, Ep Step: 500, Raw Reward: -302.50, Epsilon: 0.88
# Episode: 45, Total Steps: 22500, Ep Step: 500, Raw Reward: -313.51, Epsilon: 0.87
# Episode: 46, Total Steps: 23000, Ep Step: 500, Raw Reward: -300.67, Epsilon: 0.87
# Episode: 47, Total Steps: 23500, Ep Step: 500, Raw Reward: -304.05, Epsilon: 0.87
# Episode: 48, Total Steps: 24000, Ep Step: 500, Raw Reward: -278.01, Epsilon: 0.86
# Episode: 49, Total Steps: 24500, Ep Step: 500, Raw Reward: -289.16, Epsilon: 0.86
# Episode: 50, Total Steps: 25000, Ep Step: 500, Raw Reward: -302.79, Epsilon: 0.86
# Episode: 51, Total Steps: 25500, Ep Step: 500, Raw Reward: -305.09, Epsilon: 0.86
# Episode: 52, Total Steps: 26000, Ep Step: 500, Raw Reward: -297.85, Epsilon: 0.85
# Episode: 53, Total Steps: 26500, Ep Step: 500, Raw Reward: -291.95, Epsilon: 0.85
# Episode: 54, Total Steps: 27000, Ep Step: 500, Raw Reward: -296.28, Epsilon: 0.85
# Episode: 55, Total Steps: 27500, Ep Step: 500, Raw Reward: -305.99, Epsilon: 0.85
# Episode: 56, Total Steps: 28000, Ep Step: 500, Raw Reward: -288.39, Epsilon: 0.84
# Episode: 57, Total Steps: 28500, Ep Step: 500, Raw Reward: -290.21, Epsilon: 0.84
# Episode: 58, Total Steps: 29000, Ep Step: 500, Raw Reward: -276.49, Epsilon: 0.84
# Episode: 59, Total Steps: 29500, Ep Step: 500, Raw Reward: -309.73, Epsilon: 0.84
# Episode: 60, Total Steps: 30000, Ep Step: 500, Raw Reward: -295.67, Epsilon: 0.83
# Episode: 61, Total Steps: 30500, Ep Step: 500, Raw Reward: -302.94, Epsilon: 0.83
# Episode: 62, Total Steps: 31000, Ep Step: 500, Raw Reward: -242.62, Epsilon: 0.83
# Episode: 63, Total Steps: 31500, Ep Step: 500, Raw Reward: -229.37, Epsilon: 0.83
# Episode: 64, Total Steps: 32000, Ep Step: 500, Raw Reward: -281.83, Epsilon: 0.82
# Episode: 65, Total Steps: 32500, Ep Step: 500, Raw Reward: -186.08, Epsilon: 0.82
# Episode: 66, Total Steps: 33000, Ep Step: 500, Raw Reward: -255.49, Epsilon: 0.82
# Episode: 67, Total Steps: 33500, Ep Step: 500, Raw Reward: -310.51, Epsilon: 0.82
# Episode: 68, Total Steps: 34000, Ep Step: 500, Raw Reward: -169.64, Epsilon: 0.81
# Episode: 69, Total Steps: 34332, Ep Step: 332, Raw Reward: -10.54, Epsilon: 0.81
# Episode: 70, Total Steps: 34832, Ep Step: 500, Raw Reward: -293.58, Epsilon: 0.81
# Episode: 71, Total Steps: 35332, Ep Step: 500, Raw Reward: -315.80, Epsilon: 0.81
# Episode: 72, Total Steps: 35832, Ep Step: 500, Raw Reward: -319.81, Epsilon: 0.80
# Episode: 73, Total Steps: 36332, Ep Step: 500, Raw Reward: -258.86, Epsilon: 0.80
# Episode: 74, Total Steps: 36832, Ep Step: 500, Raw Reward: -298.02, Epsilon: 0.80
# Episode: 75, Total Steps: 37332, Ep Step: 500, Raw Reward: -307.49, Epsilon: 0.80
# Episode: 76, Total Steps: 37832, Ep Step: 500, Raw Reward: -300.29, Epsilon: 0.80
# Episode: 77, Total Steps: 38332, Ep Step: 500, Raw Reward: -322.27, Epsilon: 0.79
# Episode: 78, Total Steps: 38832, Ep Step: 500, Raw Reward: -305.09, Epsilon: 0.79
# Episode: 79, Total Steps: 39332, Ep Step: 500, Raw Reward: -252.69, Epsilon: 0.79
# Episode: 80, Total Steps: 39832, Ep Step: 500, Raw Reward: -80.24, Epsilon: 0.79
# Episode: 81, Total Steps: 40332, Ep Step: 500, Raw Reward: -303.74, Epsilon: 0.78
# Episode: 82, Total Steps: 40832, Ep Step: 500, Raw Reward: -318.15, Epsilon: 0.78
# Episode: 83, Total Steps: 41332, Ep Step: 500, Raw Reward: -324.72, Epsilon: 0.78
# Episode: 84, Total Steps: 41807, Ep Step: 475, Raw Reward: -146.58, Epsilon: 0.78
# Episode: 85, Total Steps: 42307, Ep Step: 500, Raw Reward: -128.34, Epsilon: 0.77
# Episode: 86, Total Steps: 42807, Ep Step: 500, Raw Reward: -195.81, Epsilon: 0.77
# Episode: 87, Total Steps: 43307, Ep Step: 500, Raw Reward: -148.86, Epsilon: 0.77
# Episode: 88, Total Steps: 43807, Ep Step: 500, Raw Reward: -300.32, Epsilon: 0.77
# Episode: 89, Total Steps: 44307, Ep Step: 500, Raw Reward: -97.06, Epsilon: 0.76
# Episode: 90, Total Steps: 44807, Ep Step: 500, Raw Reward: -286.38, Epsilon: 0.76
# Episode: 91, Total Steps: 45307, Ep Step: 500, Raw Reward: -285.33, Epsilon: 0.76
# Episode: 92, Total Steps: 45807, Ep Step: 500, Raw Reward: -315.64, Epsilon: 0.76
# Episode: 93, Total Steps: 46307, Ep Step: 500, Raw Reward: -317.71, Epsilon: 0.76
# Episode: 94, Total Steps: 46807, Ep Step: 500, Raw Reward: -322.02, Epsilon: 0.75
# Episode: 95, Total Steps: 47307, Ep Step: 500, Raw Reward: -311.97, Epsilon: 0.75
# Episode: 96, Total Steps: 47807, Ep Step: 500, Raw Reward: -306.42, Epsilon: 0.75
# Episode: 97, Total Steps: 48307, Ep Step: 500, Raw Reward: -313.85, Epsilon: 0.75
# Episode: 98, Total Steps: 48807, Ep Step: 500, Raw Reward: -317.64, Epsilon: 0.74
# Episode: 99, Total Steps: 49307, Ep Step: 500, Raw Reward: -320.50, Epsilon: 0.74
# ~~~~~~Interval Save: Model saved.
#
# Episode: 100, Total Steps: 49807, Ep Step: 500, Raw Reward: -256.52, Epsilon: 0.74
# Episode: 101, Total Steps: 50307, Ep Step: 500, Raw Reward: -299.15, Epsilon: 0.74
# Episode: 102, Total Steps: 50807, Ep Step: 500, Raw Reward: -318.29, Epsilon: 0.74
# Episode: 103, Total Steps: 51307, Ep Step: 500, Raw Reward: -318.44, Epsilon: 0.73
# Episode: 104, Total Steps: 51807, Ep Step: 500, Raw Reward: -86.52, Epsilon: 0.73
# Episode: 105, Total Steps: 52307, Ep Step: 500, Raw Reward: -320.95, Epsilon: 0.73
# Episode: 106, Total Steps: 52807, Ep Step: 500, Raw Reward: -326.14, Epsilon: 0.73
# Episode: 107, Total Steps: 53307, Ep Step: 500, Raw Reward: -307.20, Epsilon: 0.72
# Episode: 108, Total Steps: 53807, Ep Step: 500, Raw Reward: -321.75, Epsilon: 0.72
# Episode: 109, Total Steps: 54307, Ep Step: 500, Raw Reward: -324.76, Epsilon: 0.72
# Episode: 110, Total Steps: 54807, Ep Step: 500, Raw Reward: -300.33, Epsilon: 0.72
# Episode: 111, Total Steps: 55307, Ep Step: 500, Raw Reward: -317.91, Epsilon: 0.72
# Episode: 112, Total Steps: 55807, Ep Step: 500, Raw Reward: -140.88, Epsilon: 0.71
# Episode: 113, Total Steps: 56307, Ep Step: 500, Raw Reward: -281.81, Epsilon: 0.71
# Episode: 114, Total Steps: 56807, Ep Step: 500, Raw Reward: -128.10, Epsilon: 0.71
# Episode: 115, Total Steps: 57307, Ep Step: 500, Raw Reward: -320.60, Epsilon: 0.71
# Episode: 116, Total Steps: 57807, Ep Step: 500, Raw Reward: -325.47, Epsilon: 0.71
# Episode: 117, Total Steps: 58292, Ep Step: 485, Raw Reward: -150.06, Epsilon: 0.70
# Episode: 118, Total Steps: 58792, Ep Step: 500, Raw Reward: -320.04, Epsilon: 0.70
# Episode: 119, Total Steps: 59292, Ep Step: 500, Raw Reward: -302.05, Epsilon: 0.70
# Episode: 120, Total Steps: 59792, Ep Step: 500, Raw Reward: -319.29, Epsilon: 0.70
# Episode: 121, Total Steps: 60292, Ep Step: 500, Raw Reward: -309.72, Epsilon: 0.69
# Episode: 122, Total Steps: 60792, Ep Step: 500, Raw Reward: -280.02, Epsilon: 0.69
# Episode: 123, Total Steps: 61292, Ep Step: 500, Raw Reward: -308.70, Epsilon: 0.69
# Episode: 124, Total Steps: 61792, Ep Step: 500, Raw Reward: -220.43, Epsilon: 0.69
# Episode: 125, Total Steps: 62292, Ep Step: 500, Raw Reward: -314.40, Epsilon: 0.69
# Episode: 126, Total Steps: 62742, Ep Step: 450, Raw Reward: -146.61, Epsilon: 0.68
# Episode: 127, Total Steps: 63224, Ep Step: 482, Raw Reward: 15.00, Epsilon: 0.68
# Episode: 128, Total Steps: 63724, Ep Step: 500, Raw Reward: -242.48, Epsilon: 0.68
# Episode: 129, Total Steps: 64224, Ep Step: 500, Raw Reward: -321.10, Epsilon: 0.68
# Episode: 130, Total Steps: 64711, Ep Step: 487, Raw Reward: -170.78, Epsilon: 0.68
# Episode: 131, Total Steps: 65211, Ep Step: 500, Raw Reward: -323.41, Epsilon: 0.67
# Episode: 132, Total Steps: 65711, Ep Step: 500, Raw Reward: -322.22, Epsilon: 0.67
# Episode: 133, Total Steps: 66211, Ep Step: 500, Raw Reward: -285.65, Epsilon: 0.67
# Episode: 134, Total Steps: 66711, Ep Step: 500, Raw Reward: -263.51, Epsilon: 0.67
# Episode: 135, Total Steps: 67100, Ep Step: 389, Raw Reward: -84.73, Epsilon: 0.67
# Episode: 136, Total Steps: 67435, Ep Step: 335, Raw Reward: 21.62, Epsilon: 0.66
# Episode: 137, Total Steps: 67759, Ep Step: 324, Raw Reward: -65.01, Epsilon: 0.66
# Episode: 138, Total Steps: 68215, Ep Step: 456, Raw Reward: 130.58, Epsilon: 0.66
# Episode: 139, Total Steps: 68465, Ep Step: 250, Raw Reward: -13.67, Epsilon: 0.66
# Episode: 140, Total Steps: 68810, Ep Step: 345, Raw Reward: -64.13, Epsilon: 0.66
# Episode: 141, Total Steps: 69065, Ep Step: 255, Raw Reward: 1.12, Epsilon: 0.65
# Episode: 142, Total Steps: 69565, Ep Step: 500, Raw Reward: 200.81, Epsilon: 0.65
# Episode: 143, Total Steps: 69895, Ep Step: 330, Raw Reward: -57.10, Epsilon: 0.65
# Episode: 144, Total Steps: 70143, Ep Step: 248, Raw Reward: -27.82, Epsilon: 0.65
# Episode: 145, Total Steps: 70483, Ep Step: 340, Raw Reward: -59.41, Epsilon: 0.65
# Episode: 146, Total Steps: 70737, Ep Step: 254, Raw Reward: 9.78, Epsilon: 0.64
# Episode: 147, Total Steps: 71008, Ep Step: 271, Raw Reward: 8.42, Epsilon: 0.64
# Episode: 148, Total Steps: 71479, Ep Step: 471, Raw Reward: 274.14, Epsilon: 0.64
# Episode: 149, Total Steps: 71979, Ep Step: 500, Raw Reward: 351.37, Epsilon: 0.64
# Episode: 150, Total Steps: 72238, Ep Step: 259, Raw Reward: -26.78, Epsilon: 0.64
# Episode: 151, Total Steps: 72738, Ep Step: 500, Raw Reward: 122.13, Epsilon: 0.63
# Episode: 152, Total Steps: 72982, Ep Step: 244, Raw Reward: -39.23, Epsilon: 0.63
# Episode: 153, Total Steps: 73240, Ep Step: 258, Raw Reward: -34.06, Epsilon: 0.63
# Episode: 154, Total Steps: 73682, Ep Step: 442, Raw Reward: -72.18, Epsilon: 0.63
# Episode: 155, Total Steps: 73980, Ep Step: 298, Raw Reward: -32.77, Epsilon: 0.63
# Episode: 156, Total Steps: 74385, Ep Step: 405, Raw Reward: -94.67, Epsilon: 0.63
# Episode: 157, Total Steps: 74667, Ep Step: 282, Raw Reward: -30.36, Epsilon: 0.62
# Episode: 158, Total Steps: 75167, Ep Step: 500, Raw Reward: -326.18, Epsilon: 0.62
# Episode: 159, Total Steps: 75667, Ep Step: 500, Raw Reward: -32.24, Epsilon: 0.62
# Episode: 160, Total Steps: 76167, Ep Step: 500, Raw Reward: -233.82, Epsilon: 0.62
# Episode: 161, Total Steps: 76667, Ep Step: 500, Raw Reward: -25.45, Epsilon: 0.62
# Episode: 162, Total Steps: 77064, Ep Step: 397, Raw Reward: -125.74, Epsilon: 0.61
# Episode: 163, Total Steps: 77538, Ep Step: 474, Raw Reward: -133.68, Epsilon: 0.61
# Episode: 164, Total Steps: 78038, Ep Step: 500, Raw Reward: -263.88, Epsilon: 0.61
# Episode: 165, Total Steps: 78410, Ep Step: 372, Raw Reward: -8.00, Epsilon: 0.61
# Episode: 166, Total Steps: 78910, Ep Step: 500, Raw Reward: -321.41, Epsilon: 0.61
# Episode: 167, Total Steps: 79206, Ep Step: 296, Raw Reward: -57.41, Epsilon: 0.60
# Episode: 168, Total Steps: 79706, Ep Step: 500, Raw Reward: -328.34, Epsilon: 0.60
# Episode: 169, Total Steps: 80003, Ep Step: 297, Raw Reward: -72.73, Epsilon: 0.60
# Episode: 170, Total Steps: 80445, Ep Step: 442, Raw Reward: 86.66, Epsilon: 0.60
# Episode: 171, Total Steps: 80771, Ep Step: 326, Raw Reward: -39.25, Epsilon: 0.60
# Episode: 172, Total Steps: 81148, Ep Step: 377, Raw Reward: -95.33, Epsilon: 0.60
# Episode: 173, Total Steps: 81648, Ep Step: 500, Raw Reward: -324.67, Epsilon: 0.59
# Episode: 174, Total Steps: 82024, Ep Step: 376, Raw Reward: -108.77, Epsilon: 0.59
# Episode: 175, Total Steps: 82524, Ep Step: 500, Raw Reward: -296.09, Epsilon: 0.59
# Episode: 176, Total Steps: 82780, Ep Step: 256, Raw Reward: -49.14, Epsilon: 0.59
# Episode: 177, Total Steps: 83098, Ep Step: 318, Raw Reward: 11.85, Epsilon: 0.59
# Episode: 178, Total Steps: 83598, Ep Step: 500, Raw Reward: -266.34, Epsilon: 0.59
# Episode: 179, Total Steps: 84098, Ep Step: 500, Raw Reward: -232.43, Epsilon: 0.58
# Episode: 180, Total Steps: 84531, Ep Step: 433, Raw Reward: 17.11, Epsilon: 0.58
# Episode: 181, Total Steps: 84986, Ep Step: 455, Raw Reward: -134.88, Epsilon: 0.58
# Episode: 182, Total Steps: 85486, Ep Step: 500, Raw Reward: -328.10, Epsilon: 0.58
# Episode: 183, Total Steps: 85837, Ep Step: 351, Raw Reward: 31.28, Epsilon: 0.58
# Episode: 184, Total Steps: 86337, Ep Step: 500, Raw Reward: -225.55, Epsilon: 0.57
# Episode: 185, Total Steps: 86837, Ep Step: 500, Raw Reward: -183.87, Epsilon: 0.57
# Episode: 186, Total Steps: 87337, Ep Step: 500, Raw Reward: -262.05, Epsilon: 0.57
# Episode: 187, Total Steps: 87837, Ep Step: 500, Raw Reward: -171.25, Epsilon: 0.57
# Episode: 188, Total Steps: 88337, Ep Step: 500, Raw Reward: -237.14, Epsilon: 0.57
# Episode: 189, Total Steps: 88798, Ep Step: 461, Raw Reward: -155.32, Epsilon: 0.57
# Episode: 190, Total Steps: 89298, Ep Step: 500, Raw Reward: -327.96, Epsilon: 0.56
# Episode: 191, Total Steps: 89792, Ep Step: 494, Raw Reward: -189.84, Epsilon: 0.56
# Episode: 192, Total Steps: 90083, Ep Step: 291, Raw Reward: -73.71, Epsilon: 0.56
# Episode: 193, Total Steps: 90583, Ep Step: 500, Raw Reward: -325.84, Epsilon: 0.56
# Episode: 194, Total Steps: 91083, Ep Step: 500, Raw Reward: -284.24, Epsilon: 0.56
# Episode: 195, Total Steps: 91583, Ep Step: 500, Raw Reward: -316.03, Epsilon: 0.56
# Episode: 196, Total Steps: 91921, Ep Step: 338, Raw Reward: -114.56, Epsilon: 0.55
# Episode: 197, Total Steps: 92421, Ep Step: 500, Raw Reward: -329.25, Epsilon: 0.55
# Episode: 198, Total Steps: 92921, Ep Step: 500, Raw Reward: -319.73, Epsilon: 0.55
# Episode: 199, Total Steps: 93421, Ep Step: 500, Raw Reward: -322.84, Epsilon: 0.55
# ~~~~~~Interval Save: Model saved.
#
# Episode: 200, Total Steps: 93921, Ep Step: 500, Raw Reward: -298.31, Epsilon: 0.55
# Episode: 201, Total Steps: 94207, Ep Step: 286, Raw Reward: -38.87, Epsilon: 0.55
# Episode: 202, Total Steps: 94707, Ep Step: 500, Raw Reward: -102.65, Epsilon: 0.54
# Episode: 203, Total Steps: 95207, Ep Step: 500, Raw Reward: -328.93, Epsilon: 0.54
# Episode: 204, Total Steps: 95707, Ep Step: 500, Raw Reward: -326.46, Epsilon: 0.54
# Episode: 205, Total Steps: 96077, Ep Step: 370, Raw Reward: -35.81, Epsilon: 0.54
# Episode: 206, Total Steps: 96441, Ep Step: 364, Raw Reward: -109.26, Epsilon: 0.54
# Episode: 207, Total Steps: 96941, Ep Step: 500, Raw Reward: -325.33, Epsilon: 0.54
# Episode: 208, Total Steps: 97300, Ep Step: 359, Raw Reward: -67.86, Epsilon: 0.53
# Episode: 209, Total Steps: 97593, Ep Step: 293, Raw Reward: -10.06, Epsilon: 0.53
# Episode: 210, Total Steps: 97827, Ep Step: 234, Raw Reward: -32.30, Epsilon: 0.53
# Episode: 211, Total Steps: 98171, Ep Step: 344, Raw Reward: -84.26, Epsilon: 0.53
# Episode: 212, Total Steps: 98475, Ep Step: 304, Raw Reward: -64.48, Epsilon: 0.53
# Episode: 213, Total Steps: 98781, Ep Step: 306, Raw Reward: 70.66, Epsilon: 0.53
# Episode: 214, Total Steps: 99053, Ep Step: 272, Raw Reward: -49.54, Epsilon: 0.53
# Episode: 215, Total Steps: 99326, Ep Step: 273, Raw Reward: -37.37, Epsilon: 0.52
# Episode: 216, Total Steps: 99605, Ep Step: 279, Raw Reward: -32.99, Epsilon: 0.52
# Episode: 217, Total Steps: 99827, Ep Step: 222, Raw Reward: -16.32, Epsilon: 0.52
# Episode: 218, Total Steps: 100104, Ep Step: 277, Raw Reward: -58.75, Epsilon: 0.52
# Episode: 219, Total Steps: 100435, Ep Step: 331, Raw Reward: -96.79, Epsilon: 0.52
# Episode: 220, Total Steps: 100631, Ep Step: 196, Raw Reward: -13.64, Epsilon: 0.52
# Episode: 221, Total Steps: 100835, Ep Step: 204, Raw Reward: -24.99, Epsilon: 0.51
# Episode: 222, Total Steps: 101013, Ep Step: 178, Raw Reward: 34.98, Epsilon: 0.51
# Episode: 223, Total Steps: 101355, Ep Step: 342, Raw Reward: -81.31, Epsilon: 0.51
# Episode: 224, Total Steps: 101561, Ep Step: 206, Raw Reward: -29.09, Epsilon: 0.51
# Episode: 225, Total Steps: 101822, Ep Step: 261, Raw Reward: 72.61, Epsilon: 0.51
# Episode: 226, Total Steps: 102105, Ep Step: 283, Raw Reward: -64.33, Epsilon: 0.51
# Episode: 227, Total Steps: 102323, Ep Step: 218, Raw Reward: -17.75, Epsilon: 0.51
# Episode: 228, Total Steps: 102624, Ep Step: 301, Raw Reward: -39.71, Epsilon: 0.50
# Episode: 229, Total Steps: 102936, Ep Step: 312, Raw Reward: -60.62, Epsilon: 0.50
# Episode: 230, Total Steps: 103144, Ep Step: 208, Raw Reward: -16.66, Epsilon: 0.50
# Episode: 231, Total Steps: 103464, Ep Step: 320, Raw Reward: -82.34, Epsilon: 0.50
# Episode: 232, Total Steps: 103668, Ep Step: 204, Raw Reward: -9.70, Epsilon: 0.50
# Episode: 233, Total Steps: 103869, Ep Step: 201, Raw Reward: 12.12, Epsilon: 0.50
# Episode: 234, Total Steps: 104127, Ep Step: 258, Raw Reward: -6.84, Epsilon: 0.49
# Episode: 235, Total Steps: 104358, Ep Step: 231, Raw Reward: -30.41, Epsilon: 0.49
# Episode: 236, Total Steps: 104742, Ep Step: 384, Raw Reward: -55.43, Epsilon: 0.49
# Episode: 237, Total Steps: 104949, Ep Step: 207, Raw Reward: -18.37, Epsilon: 0.49
# Episode: 238, Total Steps: 105282, Ep Step: 333, Raw Reward: -59.08, Epsilon: 0.49
# Episode: 239, Total Steps: 105578, Ep Step: 296, Raw Reward: -60.28, Epsilon: 0.49
# Episode: 240, Total Steps: 105936, Ep Step: 358, Raw Reward: -92.87, Epsilon: 0.49
# Episode: 241, Total Steps: 106191, Ep Step: 255, Raw Reward: 5.20, Epsilon: 0.48
# Episode: 242, Total Steps: 106411, Ep Step: 220, Raw Reward: -26.67, Epsilon: 0.48
# Episode: 243, Total Steps: 106612, Ep Step: 201, Raw Reward: -7.57, Epsilon: 0.48
# Episode: 244, Total Steps: 107085, Ep Step: 473, Raw Reward: 16.04, Epsilon: 0.48
# Episode: 245, Total Steps: 107294, Ep Step: 209, Raw Reward: -16.27, Epsilon: 0.48
# Episode: 246, Total Steps: 107496, Ep Step: 202, Raw Reward: -27.33, Epsilon: 0.48
# Episode: 247, Total Steps: 107812, Ep Step: 316, Raw Reward: 109.76, Epsilon: 0.48
# Episode: 248, Total Steps: 108147, Ep Step: 335, Raw Reward: -87.21, Epsilon: 0.47
# Episode: 249, Total Steps: 108425, Ep Step: 278, Raw Reward: 159.93, Epsilon: 0.47
# Episode: 250, Total Steps: 108686, Ep Step: 261, Raw Reward: -37.21, Epsilon: 0.47
# Episode: 251, Total Steps: 108891, Ep Step: 205, Raw Reward: 14.73, Epsilon: 0.47
# Episode: 252, Total Steps: 109156, Ep Step: 265, Raw Reward: 104.69, Epsilon: 0.47
# Episode: 253, Total Steps: 109372, Ep Step: 216, Raw Reward: -8.30, Epsilon: 0.47
# Episode: 254, Total Steps: 109686, Ep Step: 314, Raw Reward: -63.83, Epsilon: 0.47
# Episode: 255, Total Steps: 109904, Ep Step: 218, Raw Reward: 44.76, Epsilon: 0.46
# Episode: 256, Total Steps: 110084, Ep Step: 180, Raw Reward: 129.90, Epsilon: 0.46
# Episode: 257, Total Steps: 110315, Ep Step: 231, Raw Reward: -33.65, Epsilon: 0.46
# Episode: 258, Total Steps: 110538, Ep Step: 223, Raw Reward: -21.80, Epsilon: 0.46
# Episode: 259, Total Steps: 110734, Ep Step: 196, Raw Reward: 18.62, Epsilon: 0.46
# Episode: 260, Total Steps: 110943, Ep Step: 209, Raw Reward: -0.95, Epsilon: 0.46
# Episode: 261, Total Steps: 111152, Ep Step: 209, Raw Reward: 24.84, Epsilon: 0.46
# Episode: 262, Total Steps: 111464, Ep Step: 312, Raw Reward: -43.03, Epsilon: 0.45
# Episode: 263, Total Steps: 111705, Ep Step: 241, Raw Reward: -52.05, Epsilon: 0.45
# Episode: 264, Total Steps: 112001, Ep Step: 296, Raw Reward: -38.58, Epsilon: 0.45
# Episode: 265, Total Steps: 112244, Ep Step: 243, Raw Reward: -11.83, Epsilon: 0.45
# Episode: 266, Total Steps: 112445, Ep Step: 201, Raw Reward: 4.89, Epsilon: 0.45
# Episode: 267, Total Steps: 112663, Ep Step: 218, Raw Reward: -22.54, Epsilon: 0.45
# Episode: 268, Total Steps: 112875, Ep Step: 212, Raw Reward: -19.19, Epsilon: 0.45
# Episode: 269, Total Steps: 113166, Ep Step: 291, Raw Reward: -57.92, Epsilon: 0.45
# Episode: 270, Total Steps: 113437, Ep Step: 271, Raw Reward: 109.94, Epsilon: 0.44
# Episode: 271, Total Steps: 113693, Ep Step: 256, Raw Reward: -28.20, Epsilon: 0.44
# Episode: 272, Total Steps: 113861, Ep Step: 168, Raw Reward: 13.69, Epsilon: 0.44
# Episode: 273, Total Steps: 114143, Ep Step: 282, Raw Reward: -26.47, Epsilon: 0.44
# Episode: 274, Total Steps: 114312, Ep Step: 169, Raw Reward: 31.73, Epsilon: 0.44
# Episode: 275, Total Steps: 114485, Ep Step: 173, Raw Reward: 27.29, Epsilon: 0.44
# Episode: 276, Total Steps: 114674, Ep Step: 189, Raw Reward: 55.47, Epsilon: 0.44
# Episode: 277, Total Steps: 114941, Ep Step: 267, Raw Reward: -2.03, Epsilon: 0.43
# Episode: 278, Total Steps: 115190, Ep Step: 249, Raw Reward: -23.39, Epsilon: 0.43
# Episode: 279, Total Steps: 115397, Ep Step: 207, Raw Reward: -8.48, Epsilon: 0.43
# Episode: 280, Total Steps: 115567, Ep Step: 170, Raw Reward: -6.90, Epsilon: 0.43
# Episode: 281, Total Steps: 115761, Ep Step: 194, Raw Reward: -12.12, Epsilon: 0.43
# Episode: 282, Total Steps: 115965, Ep Step: 204, Raw Reward: 3.99, Epsilon: 0.43
# Episode: 283, Total Steps: 116142, Ep Step: 177, Raw Reward: 20.79, Epsilon: 0.43
# Episode: 284, Total Steps: 116387, Ep Step: 245, Raw Reward: -17.83, Epsilon: 0.43
# Episode: 285, Total Steps: 116785, Ep Step: 398, Raw Reward: -91.40, Epsilon: 0.42
# Episode: 286, Total Steps: 116993, Ep Step: 208, Raw Reward: -23.41, Epsilon: 0.42
# Episode: 287, Total Steps: 117217, Ep Step: 224, Raw Reward: -25.99, Epsilon: 0.42
# Episode: 288, Total Steps: 117381, Ep Step: 164, Raw Reward: 5.28, Epsilon: 0.42
# Episode: 289, Total Steps: 117584, Ep Step: 203, Raw Reward: 4.04, Epsilon: 0.42
# Episode: 290, Total Steps: 117767, Ep Step: 183, Raw Reward: -8.65, Epsilon: 0.42
# Episode: 291, Total Steps: 117967, Ep Step: 200, Raw Reward: 6.28, Epsilon: 0.42
# Episode: 292, Total Steps: 118152, Ep Step: 185, Raw Reward: -8.46, Epsilon: 0.42
# Episode: 293, Total Steps: 118339, Ep Step: 187, Raw Reward: -2.17, Epsilon: 0.41
# Episode: 294, Total Steps: 118528, Ep Step: 189, Raw Reward: 4.16, Epsilon: 0.41
# Episode: 295, Total Steps: 118757, Ep Step: 229, Raw Reward: 31.11, Epsilon: 0.41
# Episode: 296, Total Steps: 118930, Ep Step: 173, Raw Reward: 3.43, Epsilon: 0.41
# Episode: 297, Total Steps: 119139, Ep Step: 209, Raw Reward: -11.71, Epsilon: 0.41
# Episode: 298, Total Steps: 119450, Ep Step: 311, Raw Reward: -29.85, Epsilon: 0.41
# Episode: 299, Total Steps: 119628, Ep Step: 178, Raw Reward: -10.13, Epsilon: 0.41
# ~~~~~~Interval Save: Model saved.
#
# Episode: 300, Total Steps: 119854, Ep Step: 226, Raw Reward: -17.48, Epsilon: 0.41
# Episode: 301, Total Steps: 120068, Ep Step: 214, Raw Reward: -13.98, Epsilon: 0.40
# Episode: 302, Total Steps: 120296, Ep Step: 228, Raw Reward: -9.18, Epsilon: 0.40
# Episode: 303, Total Steps: 120612, Ep Step: 316, Raw Reward: -88.83, Epsilon: 0.40
# Episode: 304, Total Steps: 120834, Ep Step: 222, Raw Reward: -7.52, Epsilon: 0.40
# Episode: 305, Total Steps: 121043, Ep Step: 209, Raw Reward: 14.46, Epsilon: 0.40
# Episode: 306, Total Steps: 121250, Ep Step: 207, Raw Reward: -34.45, Epsilon: 0.40
# Episode: 307, Total Steps: 121520, Ep Step: 270, Raw Reward: 118.12, Epsilon: 0.40
# Episode: 308, Total Steps: 121723, Ep Step: 203, Raw Reward: -11.56, Epsilon: 0.40
# Episode: 309, Total Steps: 122223, Ep Step: 500, Raw Reward: -54.54, Epsilon: 0.39
# Episode: 310, Total Steps: 122723, Ep Step: 500, Raw Reward: -334.45, Epsilon: 0.39
# Episode: 311, Total Steps: 123223, Ep Step: 500, Raw Reward: -333.14, Epsilon: 0.39
# Episode: 312, Total Steps: 123723, Ep Step: 500, Raw Reward: -332.29, Epsilon: 0.39
# Episode: 313, Total Steps: 123978, Ep Step: 255, Raw Reward: -51.75, Epsilon: 0.39
# Episode: 314, Total Steps: 124478, Ep Step: 500, Raw Reward: -328.93, Epsilon: 0.39
# Episode: 315, Total Steps: 124953, Ep Step: 475, Raw Reward: -187.34, Epsilon: 0.39
# Episode: 316, Total Steps: 125279, Ep Step: 326, Raw Reward: -108.73, Epsilon: 0.39
# Episode: 317, Total Steps: 125779, Ep Step: 500, Raw Reward: -332.99, Epsilon: 0.39
# Episode: 318, Total Steps: 126152, Ep Step: 373, Raw Reward: -111.98, Epsilon: 0.38
# Episode: 319, Total Steps: 126479, Ep Step: 327, Raw Reward: -64.64, Epsilon: 0.38
# Episode: 320, Total Steps: 126838, Ep Step: 359, Raw Reward: -100.83, Epsilon: 0.38
# Episode: 321, Total Steps: 127185, Ep Step: 347, Raw Reward: -104.02, Epsilon: 0.38
# Episode: 322, Total Steps: 127467, Ep Step: 282, Raw Reward: -66.43, Epsilon: 0.38
# Episode: 323, Total Steps: 127937, Ep Step: 470, Raw Reward: -178.98, Epsilon: 0.38
# Episode: 324, Total Steps: 128176, Ep Step: 239, Raw Reward: -39.52, Epsilon: 0.38
# Episode: 325, Total Steps: 128676, Ep Step: 500, Raw Reward: -294.86, Epsilon: 0.38
# Episode: 326, Total Steps: 128965, Ep Step: 289, Raw Reward: -69.06, Epsilon: 0.38
# Episode: 327, Total Steps: 129465, Ep Step: 500, Raw Reward: -333.62, Epsilon: 0.37
# Episode: 328, Total Steps: 129768, Ep Step: 303, Raw Reward: -95.06, Epsilon: 0.37
# Episode: 329, Total Steps: 130054, Ep Step: 286, Raw Reward: -78.22, Epsilon: 0.37
# Episode: 330, Total Steps: 130554, Ep Step: 500, Raw Reward: -334.62, Epsilon: 0.37
# Episode: 331, Total Steps: 131054, Ep Step: 500, Raw Reward: -330.37, Epsilon: 0.37
# Episode: 332, Total Steps: 131281, Ep Step: 227, Raw Reward: -38.17, Epsilon: 0.37
# Episode: 333, Total Steps: 131781, Ep Step: 500, Raw Reward: -332.97, Epsilon: 0.37
# Episode: 334, Total Steps: 132052, Ep Step: 271, Raw Reward: -63.55, Epsilon: 0.37
# Episode: 335, Total Steps: 132501, Ep Step: 449, Raw Reward: -151.32, Epsilon: 0.37
# Episode: 336, Total Steps: 133001, Ep Step: 500, Raw Reward: -333.79, Epsilon: 0.36
# Episode: 337, Total Steps: 133212, Ep Step: 211, Raw Reward: -31.00, Epsilon: 0.36
# Episode: 338, Total Steps: 133503, Ep Step: 291, Raw Reward: -44.86, Epsilon: 0.36
# Episode: 339, Total Steps: 133973, Ep Step: 470, Raw Reward: -165.71, Epsilon: 0.36
# Episode: 340, Total Steps: 134320, Ep Step: 347, Raw Reward: -112.39, Epsilon: 0.36
# Episode: 341, Total Steps: 134523, Ep Step: 203, Raw Reward: -20.30, Epsilon: 0.36
# Episode: 342, Total Steps: 134753, Ep Step: 230, Raw Reward: -40.46, Epsilon: 0.36
# Episode: 343, Total Steps: 134979, Ep Step: 226, Raw Reward: -33.93, Epsilon: 0.36
# Episode: 344, Total Steps: 135237, Ep Step: 258, Raw Reward: -49.01, Epsilon: 0.36
# Episode: 345, Total Steps: 135544, Ep Step: 307, Raw Reward: -88.27, Epsilon: 0.35
# Episode: 346, Total Steps: 136004, Ep Step: 460, Raw Reward: -195.36, Epsilon: 0.35
# Episode: 347, Total Steps: 136240, Ep Step: 236, Raw Reward: -40.68, Epsilon: 0.35
# Episode: 348, Total Steps: 136496, Ep Step: 256, Raw Reward: -47.56, Epsilon: 0.35
# Episode: 349, Total Steps: 136782, Ep Step: 286, Raw Reward: -43.33, Epsilon: 0.35
# Episode: 350, Total Steps: 137061, Ep Step: 279, Raw Reward: -71.07, Epsilon: 0.35
# Episode: 351, Total Steps: 137408, Ep Step: 347, Raw Reward: -99.18, Epsilon: 0.35
# Episode: 352, Total Steps: 137743, Ep Step: 335, Raw Reward: -102.30, Epsilon: 0.35
# Episode: 353, Total Steps: 138052, Ep Step: 309, Raw Reward: -69.49, Epsilon: 0.35
# Episode: 354, Total Steps: 138355, Ep Step: 303, Raw Reward: -42.84, Epsilon: 0.34
# Episode: 355, Total Steps: 138575, Ep Step: 220, Raw Reward: -37.18, Epsilon: 0.34
# Episode: 356, Total Steps: 138996, Ep Step: 421, Raw Reward: -150.43, Epsilon: 0.34
# Episode: 357, Total Steps: 139398, Ep Step: 402, Raw Reward: -111.39, Epsilon: 0.34
# Episode: 358, Total Steps: 139802, Ep Step: 404, Raw Reward: -152.74, Epsilon: 0.34
# Episode: 359, Total Steps: 140302, Ep Step: 500, Raw Reward: -334.51, Epsilon: 0.34
# Episode: 360, Total Steps: 140802, Ep Step: 500, Raw Reward: -334.90, Epsilon: 0.34
# Episode: 361, Total Steps: 141302, Ep Step: 500, Raw Reward: -221.15, Epsilon: 0.34
# Episode: 362, Total Steps: 141580, Ep Step: 278, Raw Reward: -54.22, Epsilon: 0.34
# Episode: 363, Total Steps: 141811, Ep Step: 231, Raw Reward: -45.51, Epsilon: 0.34
# Episode: 364, Total Steps: 141976, Ep Step: 165, Raw Reward: 7.00, Epsilon: 0.33
# Episode: 365, Total Steps: 142139, Ep Step: 163, Raw Reward: 17.91, Epsilon: 0.33
# Episode: 366, Total Steps: 142308, Ep Step: 169, Raw Reward: 3.65, Epsilon: 0.33
# Episode: 367, Total Steps: 142476, Ep Step: 168, Raw Reward: 10.44, Epsilon: 0.33
# Episode: 368, Total Steps: 142640, Ep Step: 164, Raw Reward: -6.65, Epsilon: 0.33
# Episode: 369, Total Steps: 142799, Ep Step: 159, Raw Reward: 25.38, Epsilon: 0.33
# Episode: 370, Total Steps: 142962, Ep Step: 163, Raw Reward: 18.06, Epsilon: 0.33
# Episode: 371, Total Steps: 143124, Ep Step: 162, Raw Reward: 17.00, Epsilon: 0.33
# Episode: 372, Total Steps: 143288, Ep Step: 164, Raw Reward: 5.68, Epsilon: 0.33
# Episode: 373, Total Steps: 143447, Ep Step: 159, Raw Reward: 27.88, Epsilon: 0.33
# Episode: 374, Total Steps: 143610, Ep Step: 163, Raw Reward: 11.30, Epsilon: 0.32
# Episode: 375, Total Steps: 143775, Ep Step: 165, Raw Reward: -1.01, Epsilon: 0.32
# Episode: 376, Total Steps: 143932, Ep Step: 157, Raw Reward: 17.47, Epsilon: 0.32
# Episode: 377, Total Steps: 144084, Ep Step: 152, Raw Reward: 17.25, Epsilon: 0.32
# Episode: 378, Total Steps: 144248, Ep Step: 164, Raw Reward: 9.10, Epsilon: 0.32
# Episode: 379, Total Steps: 144413, Ep Step: 165, Raw Reward: 22.67, Epsilon: 0.32
# Episode: 380, Total Steps: 144580, Ep Step: 167, Raw Reward: 15.97, Epsilon: 0.32
# Episode: 381, Total Steps: 144746, Ep Step: 166, Raw Reward: 3.99, Epsilon: 0.32
# Episode: 382, Total Steps: 144901, Ep Step: 155, Raw Reward: -0.34, Epsilon: 0.32
# Episode: 383, Total Steps: 145053, Ep Step: 152, Raw Reward: 6.55, Epsilon: 0.32
# Episode: 384, Total Steps: 145221, Ep Step: 168, Raw Reward: -6.08, Epsilon: 0.32
# Episode: 385, Total Steps: 145386, Ep Step: 165, Raw Reward: -4.09, Epsilon: 0.31
# Episode: 386, Total Steps: 145543, Ep Step: 157, Raw Reward: 1.19, Epsilon: 0.31
# Episode: 387, Total Steps: 145708, Ep Step: 165, Raw Reward: 14.23, Epsilon: 0.31
# Episode: 388, Total Steps: 145866, Ep Step: 158, Raw Reward: 13.63, Epsilon: 0.31
# Episode: 389, Total Steps: 146022, Ep Step: 156, Raw Reward: 25.05, Epsilon: 0.31
# Episode: 390, Total Steps: 146219, Ep Step: 197, Raw Reward: 18.98, Epsilon: 0.31
# Episode: 391, Total Steps: 146367, Ep Step: 148, Raw Reward: 58.89, Epsilon: 0.31
# Episode: 392, Total Steps: 146523, Ep Step: 156, Raw Reward: 5.62, Epsilon: 0.31
# Episode: 393, Total Steps: 146684, Ep Step: 161, Raw Reward: 12.57, Epsilon: 0.31
# Episode: 394, Total Steps: 146891, Ep Step: 207, Raw Reward: -9.57, Epsilon: 0.31
# Episode: 395, Total Steps: 147055, Ep Step: 164, Raw Reward: 22.19, Epsilon: 0.30
# Episode: 396, Total Steps: 147213, Ep Step: 158, Raw Reward: 1.80, Epsilon: 0.30
# Episode: 397, Total Steps: 147372, Ep Step: 159, Raw Reward: 3.38, Epsilon: 0.30
# Episode: 398, Total Steps: 147504, Ep Step: 132, Raw Reward: 95.49, Epsilon: 0.30
# Episode: 399, Total Steps: 147671, Ep Step: 167, Raw Reward: -9.64, Epsilon: 0.30
# ~~~~~~Interval Save: Model saved.
#
# Episode: 400, Total Steps: 147831, Ep Step: 160, Raw Reward: -2.56, Epsilon: 0.30
# Episode: 401, Total Steps: 148030, Ep Step: 199, Raw Reward: 7.57, Epsilon: 0.30
# Episode: 402, Total Steps: 148186, Ep Step: 156, Raw Reward: 22.19, Epsilon: 0.30
# Episode: 403, Total Steps: 148340, Ep Step: 154, Raw Reward: -1.59, Epsilon: 0.30
# Episode: 404, Total Steps: 148505, Ep Step: 165, Raw Reward: 5.27, Epsilon: 0.30
# Episode: 405, Total Steps: 148670, Ep Step: 165, Raw Reward: 32.72, Epsilon: 0.30
# Episode: 406, Total Steps: 148832, Ep Step: 162, Raw Reward: 3.97, Epsilon: 0.29
# Episode: 407, Total Steps: 148994, Ep Step: 162, Raw Reward: 4.84, Epsilon: 0.29
# Episode: 408, Total Steps: 149158, Ep Step: 164, Raw Reward: 33.43, Epsilon: 0.29
# Episode: 409, Total Steps: 149324, Ep Step: 166, Raw Reward: -2.98, Epsilon: 0.29
# Episode: 410, Total Steps: 149492, Ep Step: 168, Raw Reward: 1.61, Epsilon: 0.29
# Episode: 411, Total Steps: 149660, Ep Step: 168, Raw Reward: -3.00, Epsilon: 0.29
# Episode: 412, Total Steps: 149825, Ep Step: 165, Raw Reward: 17.78, Epsilon: 0.29
# Episode: 413, Total Steps: 149987, Ep Step: 162, Raw Reward: 9.37, Epsilon: 0.29
# Episode: 414, Total Steps: 150155, Ep Step: 168, Raw Reward: 24.63, Epsilon: 0.29
# Episode: 415, Total Steps: 150318, Ep Step: 163, Raw Reward: 12.85, Epsilon: 0.29
# Episode: 416, Total Steps: 150471, Ep Step: 153, Raw Reward: 19.00, Epsilon: 0.29
# Episode: 417, Total Steps: 150631, Ep Step: 160, Raw Reward: -0.04, Epsilon: 0.29
# Episode: 418, Total Steps: 150801, Ep Step: 170, Raw Reward: 14.05, Epsilon: 0.28
# Episode: 419, Total Steps: 150959, Ep Step: 158, Raw Reward: 11.08, Epsilon: 0.28
# Episode: 420, Total Steps: 151124, Ep Step: 165, Raw Reward: 32.18, Epsilon: 0.28
# Episode: 421, Total Steps: 151287, Ep Step: 163, Raw Reward: 11.22, Epsilon: 0.28
# Episode: 422, Total Steps: 151453, Ep Step: 166, Raw Reward: 30.87, Epsilon: 0.28
# Episode: 423, Total Steps: 151615, Ep Step: 162, Raw Reward: 18.36, Epsilon: 0.28
# Episode: 424, Total Steps: 151779, Ep Step: 164, Raw Reward: 23.19, Epsilon: 0.28
# Episode: 425, Total Steps: 151938, Ep Step: 159, Raw Reward: 29.56, Epsilon: 0.28
# Episode: 426, Total Steps: 152110, Ep Step: 172, Raw Reward: -3.24, Epsilon: 0.28
# Episode: 427, Total Steps: 152281, Ep Step: 171, Raw Reward: 1.28, Epsilon: 0.28
# Episode: 428, Total Steps: 152450, Ep Step: 169, Raw Reward: 8.20, Epsilon: 0.28
# Episode: 429, Total Steps: 152607, Ep Step: 157, Raw Reward: 10.55, Epsilon: 0.28
# Episode: 430, Total Steps: 152771, Ep Step: 164, Raw Reward: 13.34, Epsilon: 0.27
# Episode: 431, Total Steps: 152932, Ep Step: 161, Raw Reward: 23.60, Epsilon: 0.27
# Episode: 432, Total Steps: 153094, Ep Step: 162, Raw Reward: 23.07, Epsilon: 0.27
# Episode: 433, Total Steps: 153256, Ep Step: 162, Raw Reward: 2.31, Epsilon: 0.27
# Episode: 434, Total Steps: 153424, Ep Step: 168, Raw Reward: 16.49, Epsilon: 0.27
# Episode: 435, Total Steps: 153585, Ep Step: 161, Raw Reward: -3.10, Epsilon: 0.27
# Episode: 436, Total Steps: 153746, Ep Step: 161, Raw Reward: 7.08, Epsilon: 0.27
# Episode: 437, Total Steps: 153901, Ep Step: 155, Raw Reward: 4.20, Epsilon: 0.27
# Episode: 438, Total Steps: 154061, Ep Step: 160, Raw Reward: 13.65, Epsilon: 0.27
# Episode: 439, Total Steps: 154221, Ep Step: 160, Raw Reward: 0.69, Epsilon: 0.27
# Episode: 440, Total Steps: 154382, Ep Step: 161, Raw Reward: 19.42, Epsilon: 0.27
# Episode: 441, Total Steps: 154541, Ep Step: 159, Raw Reward: -1.13, Epsilon: 0.27
# Episode: 442, Total Steps: 154703, Ep Step: 162, Raw Reward: 11.10, Epsilon: 0.26
# Episode: 443, Total Steps: 154863, Ep Step: 160, Raw Reward: 17.48, Epsilon: 0.26
# Episode: 444, Total Steps: 155032, Ep Step: 169, Raw Reward: 18.10, Epsilon: 0.26
# Episode: 445, Total Steps: 155191, Ep Step: 159, Raw Reward: 3.68, Epsilon: 0.26
# Episode: 446, Total Steps: 155358, Ep Step: 167, Raw Reward: 30.42, Epsilon: 0.26
# Episode: 447, Total Steps: 155525, Ep Step: 167, Raw Reward: 21.90, Epsilon: 0.26
# Episode: 448, Total Steps: 155684, Ep Step: 159, Raw Reward: 2.77, Epsilon: 0.26
# Episode: 449, Total Steps: 155843, Ep Step: 159, Raw Reward: 3.64, Epsilon: 0.26
# Episode: 450, Total Steps: 156001, Ep Step: 158, Raw Reward: 30.34, Epsilon: 0.26
# Episode: 451, Total Steps: 156160, Ep Step: 159, Raw Reward: 19.32, Epsilon: 0.26
# Episode: 452, Total Steps: 156327, Ep Step: 167, Raw Reward: 3.17, Epsilon: 0.26
# Episode: 453, Total Steps: 156491, Ep Step: 164, Raw Reward: 25.32, Epsilon: 0.26
# Episode: 454, Total Steps: 156658, Ep Step: 167, Raw Reward: 8.65, Epsilon: 0.26
# Episode: 455, Total Steps: 156823, Ep Step: 165, Raw Reward: 10.29, Epsilon: 0.25
# Episode: 456, Total Steps: 156985, Ep Step: 162, Raw Reward: 16.32, Epsilon: 0.25
# Episode: 457, Total Steps: 157148, Ep Step: 163, Raw Reward: 12.82, Epsilon: 0.25
# Episode: 458, Total Steps: 157315, Ep Step: 167, Raw Reward: 12.86, Epsilon: 0.25
# Episode: 459, Total Steps: 157484, Ep Step: 169, Raw Reward: 16.17, Epsilon: 0.25
# Episode: 460, Total Steps: 157657, Ep Step: 173, Raw Reward: 8.42, Epsilon: 0.25
# Episode: 461, Total Steps: 157823, Ep Step: 166, Raw Reward: 19.08, Epsilon: 0.25
# Episode: 462, Total Steps: 157985, Ep Step: 162, Raw Reward: 24.58, Epsilon: 0.25
# Episode: 463, Total Steps: 158150, Ep Step: 165, Raw Reward: 6.05, Epsilon: 0.25
# Episode: 464, Total Steps: 158314, Ep Step: 164, Raw Reward: -2.10, Epsilon: 0.25
# Episode: 465, Total Steps: 158486, Ep Step: 172, Raw Reward: 32.11, Epsilon: 0.25
# Episode: 466, Total Steps: 158655, Ep Step: 169, Raw Reward: -1.00, Epsilon: 0.25
# Episode: 467, Total Steps: 158820, Ep Step: 165, Raw Reward: 21.09, Epsilon: 0.25
# Episode: 468, Total Steps: 158990, Ep Step: 170, Raw Reward: 18.21, Epsilon: 0.24
# Episode: 469, Total Steps: 159160, Ep Step: 170, Raw Reward: 34.07, Epsilon: 0.24
# Episode: 470, Total Steps: 159334, Ep Step: 174, Raw Reward: 18.39, Epsilon: 0.24
# Episode: 471, Total Steps: 159510, Ep Step: 176, Raw Reward: 20.52, Epsilon: 0.24
# Episode: 472, Total Steps: 159673, Ep Step: 163, Raw Reward: 26.92, Epsilon: 0.24
# Episode: 473, Total Steps: 159844, Ep Step: 171, Raw Reward: 3.64, Epsilon: 0.24
# Episode: 474, Total Steps: 160015, Ep Step: 171, Raw Reward: 4.39, Epsilon: 0.24
# Episode: 475, Total Steps: 160185, Ep Step: 170, Raw Reward: -6.95, Epsilon: 0.24
# Episode: 476, Total Steps: 160360, Ep Step: 175, Raw Reward: -0.53, Epsilon: 0.24
# Episode: 477, Total Steps: 160533, Ep Step: 173, Raw Reward: 1.56, Epsilon: 0.24
# Episode: 478, Total Steps: 160700, Ep Step: 167, Raw Reward: 16.12, Epsilon: 0.24
# Episode: 479, Total Steps: 160871, Ep Step: 171, Raw Reward: 16.93, Epsilon: 0.24
# Episode: 480, Total Steps: 161057, Ep Step: 186, Raw Reward: 34.65, Epsilon: 0.24
# Episode: 481, Total Steps: 161300, Ep Step: 243, Raw Reward: -48.96, Epsilon: 0.24
# Episode: 482, Total Steps: 161478, Ep Step: 178, Raw Reward: 21.33, Epsilon: 0.23
# Episode: 483, Total Steps: 161654, Ep Step: 176, Raw Reward: 31.01, Epsilon: 0.23
# Episode: 484, Total Steps: 161823, Ep Step: 169, Raw Reward: 5.17, Epsilon: 0.23
# Episode: 485, Total Steps: 162004, Ep Step: 181, Raw Reward: 76.06, Epsilon: 0.23
# Episode: 486, Total Steps: 162182, Ep Step: 178, Raw Reward: 15.84, Epsilon: 0.23
# Episode: 487, Total Steps: 162351, Ep Step: 169, Raw Reward: 24.85, Epsilon: 0.23
# Episode: 488, Total Steps: 162520, Ep Step: 169, Raw Reward: 16.22, Epsilon: 0.23
# Episode: 489, Total Steps: 162838, Ep Step: 318, Raw Reward: -74.10, Epsilon: 0.23
# Episode: 490, Total Steps: 163086, Ep Step: 248, Raw Reward: -47.88, Epsilon: 0.23
# Episode: 491, Total Steps: 163259, Ep Step: 173, Raw Reward: 4.13, Epsilon: 0.23
# Episode: 492, Total Steps: 163759, Ep Step: 500, Raw Reward: -237.62, Epsilon: 0.23
# Episode: 493, Total Steps: 163923, Ep Step: 164, Raw Reward: 0.41, Epsilon: 0.23
# Episode: 494, Total Steps: 164094, Ep Step: 171, Raw Reward: 16.77, Epsilon: 0.23
# Episode: 495, Total Steps: 164268, Ep Step: 174, Raw Reward: 9.55, Epsilon: 0.23
# Episode: 496, Total Steps: 164444, Ep Step: 176, Raw Reward: 21.00, Epsilon: 0.23
# Episode: 497, Total Steps: 164944, Ep Step: 500, Raw Reward: -284.36, Epsilon: 0.22
# Episode: 498, Total Steps: 165189, Ep Step: 245, Raw Reward: -39.96, Epsilon: 0.22
# Episode: 499, Total Steps: 165470, Ep Step: 281, Raw Reward: 155.59, Epsilon: 0.22
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 165640, Ep Step: 170, Raw Reward: 7.77, Epsilon: 0.22
# Episode: 501, Total Steps: 165808, Ep Step: 168, Raw Reward: 5.30, Epsilon: 0.22
# Episode: 502, Total Steps: 165985, Ep Step: 177, Raw Reward: 29.82, Epsilon: 0.22
# Episode: 503, Total Steps: 166379, Ep Step: 394, Raw Reward: -105.19, Epsilon: 0.22
# Episode: 504, Total Steps: 166622, Ep Step: 243, Raw Reward: -17.67, Epsilon: 0.22
# Episode: 505, Total Steps: 166790, Ep Step: 168, Raw Reward: 16.82, Epsilon: 0.22
# Episode: 506, Total Steps: 167060, Ep Step: 270, Raw Reward: 49.59, Epsilon: 0.22
# Episode: 507, Total Steps: 167242, Ep Step: 182, Raw Reward: 11.13, Epsilon: 0.22
# Episode: 508, Total Steps: 167411, Ep Step: 169, Raw Reward: -2.51, Epsilon: 0.22
# Episode: 509, Total Steps: 167584, Ep Step: 173, Raw Reward: 10.29, Epsilon: 0.22
# Episode: 510, Total Steps: 167757, Ep Step: 173, Raw Reward: 10.62, Epsilon: 0.22
# Episode: 511, Total Steps: 167962, Ep Step: 205, Raw Reward: 176.57, Epsilon: 0.22
# Episode: 512, Total Steps: 168218, Ep Step: 256, Raw Reward: -28.73, Epsilon: 0.21
# Episode: 513, Total Steps: 168390, Ep Step: 172, Raw Reward: 3.56, Epsilon: 0.21
# Episode: 514, Total Steps: 168643, Ep Step: 253, Raw Reward: -28.00, Epsilon: 0.21
# Episode: 515, Total Steps: 168819, Ep Step: 176, Raw Reward: 9.58, Epsilon: 0.21
# Episode: 516, Total Steps: 169096, Ep Step: 277, Raw Reward: -5.14, Epsilon: 0.21
# Episode: 517, Total Steps: 169290, Ep Step: 194, Raw Reward: 33.43, Epsilon: 0.21
# Episode: 518, Total Steps: 169463, Ep Step: 173, Raw Reward: 13.04, Epsilon: 0.21
# Episode: 519, Total Steps: 169640, Ep Step: 177, Raw Reward: 6.23, Epsilon: 0.21
# Episode: 520, Total Steps: 169810, Ep Step: 170, Raw Reward: 16.29, Epsilon: 0.21
# Episode: 521, Total Steps: 169994, Ep Step: 184, Raw Reward: 28.64, Epsilon: 0.21
# Episode: 522, Total Steps: 170254, Ep Step: 260, Raw Reward: -20.77, Epsilon: 0.21
# Episode: 523, Total Steps: 170514, Ep Step: 260, Raw Reward: -49.89, Epsilon: 0.21
# Episode: 524, Total Steps: 170689, Ep Step: 175, Raw Reward: 12.19, Epsilon: 0.21
# Episode: 525, Total Steps: 170870, Ep Step: 181, Raw Reward: 16.80, Epsilon: 0.21
# Episode: 526, Total Steps: 171111, Ep Step: 241, Raw Reward: -44.60, Epsilon: 0.21
# Episode: 527, Total Steps: 171288, Ep Step: 177, Raw Reward: -4.67, Epsilon: 0.21
# Episode: 528, Total Steps: 171619, Ep Step: 331, Raw Reward: -59.08, Epsilon: 0.20
# Episode: 529, Total Steps: 171789, Ep Step: 170, Raw Reward: 1.31, Epsilon: 0.20
# Episode: 530, Total Steps: 171965, Ep Step: 176, Raw Reward: 18.77, Epsilon: 0.20
# Episode: 531, Total Steps: 172448, Ep Step: 483, Raw Reward: -180.83, Epsilon: 0.20
# Episode: 532, Total Steps: 172626, Ep Step: 178, Raw Reward: -10.29, Epsilon: 0.20
# Episode: 533, Total Steps: 172798, Ep Step: 172, Raw Reward: -5.97, Epsilon: 0.20
# Episode: 534, Total Steps: 172971, Ep Step: 173, Raw Reward: -12.54, Epsilon: 0.20
# Episode: 535, Total Steps: 173148, Ep Step: 177, Raw Reward: 18.51, Epsilon: 0.20
# Episode: 536, Total Steps: 173329, Ep Step: 181, Raw Reward: 0.79, Epsilon: 0.20
# Episode: 537, Total Steps: 173666, Ep Step: 337, Raw Reward: -98.49, Epsilon: 0.20
# Episode: 538, Total Steps: 173846, Ep Step: 180, Raw Reward: -12.61, Epsilon: 0.20
# Episode: 539, Total Steps: 174020, Ep Step: 174, Raw Reward: 13.17, Epsilon: 0.20
# Episode: 540, Total Steps: 174338, Ep Step: 318, Raw Reward: -83.03, Epsilon: 0.20
# Episode: 541, Total Steps: 174517, Ep Step: 179, Raw Reward: 29.74, Epsilon: 0.20
# Episode: 542, Total Steps: 174692, Ep Step: 175, Raw Reward: -10.74, Epsilon: 0.20
# Episode: 543, Total Steps: 174862, Ep Step: 170, Raw Reward: 11.81, Epsilon: 0.20
# Episode: 544, Total Steps: 175034, Ep Step: 172, Raw Reward: 10.50, Epsilon: 0.19
# Episode: 545, Total Steps: 175210, Ep Step: 176, Raw Reward: -6.08, Epsilon: 0.19
# Episode: 546, Total Steps: 175389, Ep Step: 179, Raw Reward: 7.85, Epsilon: 0.19
# Episode: 547, Total Steps: 175566, Ep Step: 177, Raw Reward: 14.09, Epsilon: 0.19
# Episode: 548, Total Steps: 175744, Ep Step: 178, Raw Reward: 14.22, Epsilon: 0.19
# Episode: 549, Total Steps: 175914, Ep Step: 170, Raw Reward: 24.03, Epsilon: 0.19
# Episode: 550, Total Steps: 176087, Ep Step: 173, Raw Reward: 7.61, Epsilon: 0.19
# Episode: 551, Total Steps: 176257, Ep Step: 170, Raw Reward: 0.72, Epsilon: 0.19
# Episode: 552, Total Steps: 176509, Ep Step: 252, Raw Reward: -42.19, Epsilon: 0.19
# Episode: 553, Total Steps: 176691, Ep Step: 182, Raw Reward: 9.75, Epsilon: 0.19
# Episode: 554, Total Steps: 176865, Ep Step: 174, Raw Reward: 32.62, Epsilon: 0.19
# Episode: 555, Total Steps: 177037, Ep Step: 172, Raw Reward: 19.16, Epsilon: 0.19
# Episode: 556, Total Steps: 177214, Ep Step: 177, Raw Reward: 2.37, Epsilon: 0.19
# Episode: 557, Total Steps: 177385, Ep Step: 171, Raw Reward: 19.94, Epsilon: 0.19
# Episode: 558, Total Steps: 177633, Ep Step: 248, Raw Reward: -48.65, Epsilon: 0.19
# Episode: 559, Total Steps: 177800, Ep Step: 167, Raw Reward: -6.53, Epsilon: 0.19
# Episode: 560, Total Steps: 177966, Ep Step: 166, Raw Reward: 12.06, Epsilon: 0.19
# Episode: 561, Total Steps: 178138, Ep Step: 172, Raw Reward: 1.77, Epsilon: 0.19
# Episode: 562, Total Steps: 178305, Ep Step: 167, Raw Reward: 27.48, Epsilon: 0.18
# Episode: 563, Total Steps: 178482, Ep Step: 177, Raw Reward: 18.90, Epsilon: 0.18
# Episode: 564, Total Steps: 178662, Ep Step: 180, Raw Reward: 32.63, Epsilon: 0.18
# Episode: 565, Total Steps: 178830, Ep Step: 168, Raw Reward: 10.84, Epsilon: 0.18
# Episode: 566, Total Steps: 179004, Ep Step: 174, Raw Reward: -6.28, Epsilon: 0.18
# Episode: 567, Total Steps: 179176, Ep Step: 172, Raw Reward: 2.81, Epsilon: 0.18
# Episode: 568, Total Steps: 179342, Ep Step: 166, Raw Reward: 8.30, Epsilon: 0.18
# Episode: 569, Total Steps: 179514, Ep Step: 172, Raw Reward: 38.31, Epsilon: 0.18
# Episode: 570, Total Steps: 179685, Ep Step: 171, Raw Reward: 10.93, Epsilon: 0.18
# Episode: 571, Total Steps: 179861, Ep Step: 176, Raw Reward: 32.12, Epsilon: 0.18
# Episode: 572, Total Steps: 180029, Ep Step: 168, Raw Reward: 0.70, Epsilon: 0.18
# Episode: 573, Total Steps: 180209, Ep Step: 180, Raw Reward: 25.99, Epsilon: 0.18
# Episode: 574, Total Steps: 180389, Ep Step: 180, Raw Reward: 18.44, Epsilon: 0.18
# Episode: 575, Total Steps: 180576, Ep Step: 187, Raw Reward: -18.12, Epsilon: 0.18
# Episode: 576, Total Steps: 180739, Ep Step: 163, Raw Reward: 10.56, Epsilon: 0.18
# Episode: 577, Total Steps: 180910, Ep Step: 171, Raw Reward: 40.11, Epsilon: 0.18
# Episode: 578, Total Steps: 181081, Ep Step: 171, Raw Reward: 7.72, Epsilon: 0.18
# Episode: 579, Total Steps: 181268, Ep Step: 187, Raw Reward: 38.95, Epsilon: 0.18
# Episode: 580, Total Steps: 181434, Ep Step: 166, Raw Reward: 24.65, Epsilon: 0.17
# Episode: 581, Total Steps: 181611, Ep Step: 177, Raw Reward: 12.62, Epsilon: 0.17
# ...
# Episode: 808, Total Steps: 219798, Ep Step: 172, Raw Reward: 37.22, Epsilon: 0.09
# Episode: 809, Total Steps: 219971, Ep Step: 173, Raw Reward: 35.95, Epsilon: 0.09
# Episode: 810, Total Steps: 220145, Ep Step: 174, Raw Reward: 29.17, Epsilon: 0.09
# Episode: 811, Total Steps: 220330, Ep Step: 185, Raw Reward: 45.05, Epsilon: 0.09
# Episode: 812, Total Steps: 220508, Ep Step: 178, Raw Reward: 40.58, Epsilon: 0.09
# Episode: 813, Total Steps: 220679, Ep Step: 171, Raw Reward: 40.48, Epsilon: 0.09
# Episode: 814, Total Steps: 220849, Ep Step: 170, Raw Reward: 36.84, Epsilon: 0.09
# Episode: 815, Total Steps: 221015, Ep Step: 166, Raw Reward: 29.42, Epsilon: 0.09
# Episode: 816, Total Steps: 221180, Ep Step: 165, Raw Reward: 27.59, Epsilon: 0.09
# Episode: 817, Total Steps: 221352, Ep Step: 172, Raw Reward: 41.15, Epsilon: 0.09
# Episode: 818, Total Steps: 221521, Ep Step: 169, Raw Reward: 33.29, Epsilon: 0.09
# Episode: 819, Total Steps: 221688, Ep Step: 167, Raw Reward: 33.00, Epsilon: 0.09
# Episode: 820, Total Steps: 221861, Ep Step: 173, Raw Reward: 26.74, Epsilon: 0.09
# Episode: 821, Total Steps: 222033, Ep Step: 172, Raw Reward: 40.33, Epsilon: 0.08
# Episode: 822, Total Steps: 222207, Ep Step: 174, Raw Reward: 41.96, Epsilon: 0.08
# Episode: 823, Total Steps: 222374, Ep Step: 167, Raw Reward: 34.29, Epsilon: 0.08
# Episode: 824, Total Steps: 222549, Ep Step: 175, Raw Reward: 30.26, Epsilon: 0.08
# Episode: 825, Total Steps: 222718, Ep Step: 169, Raw Reward: 35.94, Epsilon: 0.08
# Episode: 826, Total Steps: 222893, Ep Step: 175, Raw Reward: 45.09, Epsilon: 0.08
# Episode: 827, Total Steps: 223063, Ep Step: 170, Raw Reward: 39.99, Epsilon: 0.08
# Episode: 828, Total Steps: 223261, Ep Step: 198, Raw Reward: 225.14, Epsilon: 0.08
# Episode: 829, Total Steps: 223432, Ep Step: 171, Raw Reward: 32.70, Epsilon: 0.08
# Episode: 830, Total Steps: 223610, Ep Step: 178, Raw Reward: 49.00, Epsilon: 0.08
# Episode: 831, Total Steps: 223790, Ep Step: 180, Raw Reward: 49.17, Epsilon: 0.08
# Episode: 832, Total Steps: 223966, Ep Step: 176, Raw Reward: 40.00, Epsilon: 0.08
# Episode: 833, Total Steps: 224134, Ep Step: 168, Raw Reward: 32.07, Epsilon: 0.08
# Episode: 834, Total Steps: 224324, Ep Step: 190, Raw Reward: 140.03, Epsilon: 0.08
# Episode: 835, Total Steps: 224493, Ep Step: 169, Raw Reward: 40.86, Epsilon: 0.08
# Episode: 836, Total Steps: 224674, Ep Step: 181, Raw Reward: 47.24, Epsilon: 0.08
# Episode: 837, Total Steps: 224834, Ep Step: 160, Raw Reward: 27.69, Epsilon: 0.08
# Episode: 838, Total Steps: 224999, Ep Step: 165, Raw Reward: 32.75, Epsilon: 0.08
# Episode: 839, Total Steps: 225164, Ep Step: 165, Raw Reward: 36.71, Epsilon: 0.08
# Episode: 840, Total Steps: 225333, Ep Step: 169, Raw Reward: 41.99, Epsilon: 0.08
# Episode: 841, Total Steps: 225501, Ep Step: 168, Raw Reward: 42.75, Epsilon: 0.08
# Episode: 842, Total Steps: 225668, Ep Step: 167, Raw Reward: 36.76, Epsilon: 0.08
# Episode: 843, Total Steps: 225848, Ep Step: 180, Raw Reward: 31.38, Epsilon: 0.08
# Episode: 844, Total Steps: 226024, Ep Step: 176, Raw Reward: 42.95, Epsilon: 0.08
# Episode: 845, Total Steps: 226195, Ep Step: 171, Raw Reward: 43.18, Epsilon: 0.08
# Episode: 846, Total Steps: 226362, Ep Step: 167, Raw Reward: 26.72, Epsilon: 0.08
# Episode: 847, Total Steps: 226530, Ep Step: 168, Raw Reward: 38.17, Epsilon: 0.08
# Episode: 848, Total Steps: 226701, Ep Step: 171, Raw Reward: 29.81, Epsilon: 0.08
# Episode: 849, Total Steps: 226863, Ep Step: 162, Raw Reward: 18.35, Epsilon: 0.08
# Episode: 850, Total Steps: 227036, Ep Step: 173, Raw Reward: 42.21, Epsilon: 0.08
# Episode: 851, Total Steps: 227221, Ep Step: 185, Raw Reward: 116.65, Epsilon: 0.08
# Episode: 852, Total Steps: 227396, Ep Step: 175, Raw Reward: 45.52, Epsilon: 0.08
# Episode: 853, Total Steps: 227571, Ep Step: 175, Raw Reward: 46.33, Epsilon: 0.08
# Episode: 854, Total Steps: 227734, Ep Step: 163, Raw Reward: 36.28, Epsilon: 0.08
# Episode: 855, Total Steps: 227908, Ep Step: 174, Raw Reward: 32.91, Epsilon: 0.08
# Episode: 856, Total Steps: 228075, Ep Step: 167, Raw Reward: 40.50, Epsilon: 0.08
# Episode: 857, Total Steps: 228258, Ep Step: 183, Raw Reward: 50.73, Epsilon: 0.08
# Episode: 858, Total Steps: 228435, Ep Step: 177, Raw Reward: 45.13, Epsilon: 0.08
# Episode: 859, Total Steps: 228609, Ep Step: 174, Raw Reward: 41.96, Epsilon: 0.08
# Episode: 860, Total Steps: 228778, Ep Step: 169, Raw Reward: 37.00, Epsilon: 0.08
# Episode: 861, Total Steps: 228953, Ep Step: 175, Raw Reward: 45.02, Epsilon: 0.08
# Episode: 862, Total Steps: 229120, Ep Step: 167, Raw Reward: 37.16, Epsilon: 0.07
# Episode: 863, Total Steps: 229315, Ep Step: 195, Raw Reward: 205.67, Epsilon: 0.07
# Episode: 864, Total Steps: 229523, Ep Step: 208, Raw Reward: 281.36, Epsilon: 0.07
# Episode: 865, Total Steps: 229695, Ep Step: 172, Raw Reward: 40.02, Epsilon: 0.07
# Episode: 866, Total Steps: 229866, Ep Step: 171, Raw Reward: 38.21, Epsilon: 0.07
# Episode: 867, Total Steps: 230026, Ep Step: 160, Raw Reward: 23.48, Epsilon: 0.07
# Episode: 868, Total Steps: 230206, Ep Step: 180, Raw Reward: 45.83, Epsilon: 0.07
# Episode: 869, Total Steps: 230322, Ep Step: 116, Raw Reward: 162.15, Epsilon: 0.07
# Episode: 870, Total Steps: 230489, Ep Step: 167, Raw Reward: 36.21, Epsilon: 0.07
# Episode: 871, Total Steps: 230657, Ep Step: 168, Raw Reward: 32.39, Epsilon: 0.07
# Episode: 872, Total Steps: 230840, Ep Step: 183, Raw Reward: 140.49, Epsilon: 0.07
# Episode: 873, Total Steps: 231000, Ep Step: 160, Raw Reward: 28.21, Epsilon: 0.07
# Episode: 874, Total Steps: 231169, Ep Step: 169, Raw Reward: 44.44, Epsilon: 0.07
# Episode: 875, Total Steps: 231339, Ep Step: 170, Raw Reward: 39.16, Epsilon: 0.07
# Episode: 876, Total Steps: 231504, Ep Step: 165, Raw Reward: 38.54, Epsilon: 0.07
# Episode: 877, Total Steps: 231669, Ep Step: 165, Raw Reward: 44.15, Epsilon: 0.07
# Episode: 878, Total Steps: 231846, Ep Step: 177, Raw Reward: 47.21, Epsilon: 0.07
# Episode: 879, Total Steps: 232006, Ep Step: 160, Raw Reward: 31.31, Epsilon: 0.07
# Episode: 880, Total Steps: 232185, Ep Step: 179, Raw Reward: 47.41, Epsilon: 0.07
# Episode: 881, Total Steps: 232344, Ep Step: 159, Raw Reward: 36.70, Epsilon: 0.07
# Episode: 882, Total Steps: 232512, Ep Step: 168, Raw Reward: 39.11, Epsilon: 0.07
# Episode: 883, Total Steps: 232626, Ep Step: 114, Raw Reward: 164.45, Epsilon: 0.07
# Episode: 884, Total Steps: 232807, Ep Step: 181, Raw Reward: 46.98, Epsilon: 0.07
# Episode: 885, Total Steps: 232989, Ep Step: 182, Raw Reward: 78.74, Epsilon: 0.07
# Episode: 886, Total Steps: 233160, Ep Step: 171, Raw Reward: 41.43, Epsilon: 0.07
# Episode: 887, Total Steps: 233326, Ep Step: 166, Raw Reward: 32.55, Epsilon: 0.07
# Episode: 888, Total Steps: 233496, Ep Step: 170, Raw Reward: 45.25, Epsilon: 0.07
# Episode: 889, Total Steps: 233663, Ep Step: 167, Raw Reward: 35.78, Epsilon: 0.07
# Episode: 890, Total Steps: 233762, Ep Step: 99, Raw Reward: 83.31, Epsilon: 0.07
# Episode: 891, Total Steps: 233942, Ep Step: 180, Raw Reward: 56.95, Epsilon: 0.07
# Episode: 892, Total Steps: 234115, Ep Step: 173, Raw Reward: 43.67, Epsilon: 0.07
# Episode: 893, Total Steps: 234282, Ep Step: 167, Raw Reward: 35.29, Epsilon: 0.07
# Episode: 894, Total Steps: 234463, Ep Step: 181, Raw Reward: 36.78, Epsilon: 0.07
# Episode: 895, Total Steps: 234640, Ep Step: 177, Raw Reward: 45.79, Epsilon: 0.07
# Episode: 896, Total Steps: 234818, Ep Step: 178, Raw Reward: 48.58, Epsilon: 0.07
# Episode: 897, Total Steps: 234993, Ep Step: 175, Raw Reward: 44.78, Epsilon: 0.07
# Episode: 898, Total Steps: 235162, Ep Step: 169, Raw Reward: 41.10, Epsilon: 0.07
# Episode: 899, Total Steps: 235338, Ep Step: 176, Raw Reward: 47.17, Epsilon: 0.07
# ~~~~~~Interval Save: Model saved.
#
# Episode: 900, Total Steps: 235509, Ep Step: 171, Raw Reward: 39.98, Epsilon: 0.07
# Episode: 901, Total Steps: 235642, Ep Step: 133, Raw Reward: 288.19, Epsilon: 0.07
# Episode: 902, Total Steps: 235813, Ep Step: 171, Raw Reward: 39.40, Epsilon: 0.07
# Episode: 903, Total Steps: 235943, Ep Step: 130, Raw Reward: 253.58, Epsilon: 0.07
# Episode: 904, Total Steps: 236116, Ep Step: 173, Raw Reward: 39.53, Epsilon: 0.07
# Episode: 905, Total Steps: 236228, Ep Step: 112, Raw Reward: 161.96, Epsilon: 0.07
# Episode: 906, Total Steps: 236395, Ep Step: 167, Raw Reward: 30.87, Epsilon: 0.07
# Episode: 907, Total Steps: 236588, Ep Step: 193, Raw Reward: 171.56, Epsilon: 0.07
# Episode: 908, Total Steps: 236757, Ep Step: 169, Raw Reward: 38.53, Epsilon: 0.07
# Episode: 909, Total Steps: 236919, Ep Step: 162, Raw Reward: 33.65, Epsilon: 0.07
# Episode: 910, Total Steps: 237077, Ep Step: 158, Raw Reward: 29.89, Epsilon: 0.06
# Episode: 911, Total Steps: 237236, Ep Step: 159, Raw Reward: 35.17, Epsilon: 0.06
# Episode: 912, Total Steps: 237405, Ep Step: 169, Raw Reward: 45.55, Epsilon: 0.06
# Episode: 913, Total Steps: 237572, Ep Step: 167, Raw Reward: 33.85, Epsilon: 0.06
# Episode: 914, Total Steps: 237677, Ep Step: 105, Raw Reward: 121.78, Epsilon: 0.06
# Episode: 915, Total Steps: 237861, Ep Step: 184, Raw Reward: 95.30, Epsilon: 0.06
# Episode: 916, Total Steps: 238032, Ep Step: 171, Raw Reward: 45.35, Epsilon: 0.06
# Episode: 917, Total Steps: 238209, Ep Step: 177, Raw Reward: 46.96, Epsilon: 0.06
# Episode: 918, Total Steps: 238370, Ep Step: 161, Raw Reward: 29.46, Epsilon: 0.06
# Episode: 919, Total Steps: 238565, Ep Step: 195, Raw Reward: 215.97, Epsilon: 0.06
# Episode: 920, Total Steps: 238676, Ep Step: 111, Raw Reward: 160.01, Epsilon: 0.06
# Episode: 921, Total Steps: 238853, Ep Step: 177, Raw Reward: 44.74, Epsilon: 0.06
# Episode: 922, Total Steps: 239001, Ep Step: 148, Raw Reward: 371.62, Epsilon: 0.06
# Episode: 923, Total Steps: 239163, Ep Step: 162, Raw Reward: 39.32, Epsilon: 0.06
# Episode: 924, Total Steps: 239326, Ep Step: 163, Raw Reward: 39.52, Epsilon: 0.06
# Episode: 925, Total Steps: 239507, Ep Step: 181, Raw Reward: 46.10, Epsilon: 0.06
# Episode: 926, Total Steps: 239684, Ep Step: 177, Raw Reward: 46.65, Epsilon: 0.06
# Episode: 927, Total Steps: 239851, Ep Step: 167, Raw Reward: 38.64, Epsilon: 0.06
# Episode: 928, Total Steps: 240040, Ep Step: 189, Raw Reward: 167.67, Epsilon: 0.06
# Episode: 929, Total Steps: 240228, Ep Step: 188, Raw Reward: 150.36, Epsilon: 0.06
# Episode: 930, Total Steps: 240412, Ep Step: 184, Raw Reward: 48.00, Epsilon: 0.06
# Episode: 931, Total Steps: 240584, Ep Step: 172, Raw Reward: 29.95, Epsilon: 0.06
# Episode: 932, Total Steps: 240771, Ep Step: 187, Raw Reward: 138.96, Epsilon: 0.06
# Episode: 933, Total Steps: 240944, Ep Step: 173, Raw Reward: 46.13, Epsilon: 0.06
# Episode: 934, Total Steps: 241114, Ep Step: 170, Raw Reward: 30.60, Epsilon: 0.06
# Episode: 935, Total Steps: 241287, Ep Step: 173, Raw Reward: 44.81, Epsilon: 0.06
# Episode: 936, Total Steps: 241458, Ep Step: 171, Raw Reward: 44.19, Epsilon: 0.06
# Episode: 937, Total Steps: 241638, Ep Step: 180, Raw Reward: 48.16, Epsilon: 0.06
# Episode: 938, Total Steps: 241822, Ep Step: 184, Raw Reward: 131.72, Epsilon: 0.06
# Episode: 939, Total Steps: 241920, Ep Step: 98, Raw Reward: 105.05, Epsilon: 0.06
# Episode: 940, Total Steps: 242030, Ep Step: 110, Raw Reward: 148.07, Epsilon: 0.06
# Episode: 941, Total Steps: 242205, Ep Step: 175, Raw Reward: 38.55, Epsilon: 0.06
# Episode: 942, Total Steps: 242386, Ep Step: 181, Raw Reward: 117.78, Epsilon: 0.06
# Episode: 943, Total Steps: 242566, Ep Step: 180, Raw Reward: 49.29, Epsilon: 0.06
# Episode: 944, Total Steps: 242750, Ep Step: 184, Raw Reward: 99.93, Epsilon: 0.06
# Episode: 945, Total Steps: 242937, Ep Step: 187, Raw Reward: 168.05, Epsilon: 0.06
# Episode: 946, Total Steps: 243110, Ep Step: 173, Raw Reward: 40.51, Epsilon: 0.06
# Episode: 947, Total Steps: 243279, Ep Step: 169, Raw Reward: 44.75, Epsilon: 0.06
# Episode: 948, Total Steps: 243441, Ep Step: 162, Raw Reward: 33.93, Epsilon: 0.06
# Episode: 949, Total Steps: 243544, Ep Step: 103, Raw Reward: 122.46, Epsilon: 0.06
# Episode: 950, Total Steps: 243742, Ep Step: 198, Raw Reward: 252.72, Epsilon: 0.06
# Episode: 951, Total Steps: 243911, Ep Step: 169, Raw Reward: 44.36, Epsilon: 0.06
# Episode: 952, Total Steps: 244030, Ep Step: 119, Raw Reward: 217.88, Epsilon: 0.06
# Episode: 953, Total Steps: 244205, Ep Step: 175, Raw Reward: 43.77, Epsilon: 0.06
# Episode: 954, Total Steps: 244386, Ep Step: 181, Raw Reward: 96.43, Epsilon: 0.06
# Episode: 955, Total Steps: 244497, Ep Step: 111, Raw Reward: 172.05, Epsilon: 0.06
# Episode: 956, Total Steps: 244668, Ep Step: 171, Raw Reward: 38.67, Epsilon: 0.06
# Episode: 957, Total Steps: 244850, Ep Step: 182, Raw Reward: 49.00, Epsilon: 0.06
# Episode: 958, Total Steps: 245023, Ep Step: 173, Raw Reward: 39.88, Epsilon: 0.06
# Episode: 959, Total Steps: 245196, Ep Step: 173, Raw Reward: 46.65, Epsilon: 0.06
# Episode: 960, Total Steps: 245395, Ep Step: 199, Raw Reward: 255.45, Epsilon: 0.06
# Episode: 961, Total Steps: 245588, Ep Step: 193, Raw Reward: 212.11, Epsilon: 0.06
# Episode: 962, Total Steps: 245705, Ep Step: 117, Raw Reward: 203.71, Epsilon: 0.06
# Episode: 963, Total Steps: 245804, Ep Step: 99, Raw Reward: 111.38, Epsilon: 0.06
# Episode: 964, Total Steps: 245973, Ep Step: 169, Raw Reward: 44.39, Epsilon: 0.06
# Episode: 965, Total Steps: 246154, Ep Step: 181, Raw Reward: 124.84, Epsilon: 0.06
# Episode: 966, Total Steps: 246252, Ep Step: 98, Raw Reward: 105.78, Epsilon: 0.05
# Episode: 967, Total Steps: 246438, Ep Step: 186, Raw Reward: 179.87, Epsilon: 0.05
# Episode: 968, Total Steps: 246605, Ep Step: 167, Raw Reward: 41.71, Epsilon: 0.05
# Episode: 969, Total Steps: 246768, Ep Step: 163, Raw Reward: 35.24, Epsilon: 0.05
# Episode: 970, Total Steps: 246936, Ep Step: 168, Raw Reward: 40.67, Epsilon: 0.05
# Episode: 971, Total Steps: 247033, Ep Step: 97, Raw Reward: 89.90, Epsilon: 0.05
# Episode: 972, Total Steps: 247146, Ep Step: 113, Raw Reward: 181.79, Epsilon: 0.05
# Episode: 973, Total Steps: 247320, Ep Step: 174, Raw Reward: 44.63, Epsilon: 0.05
# Episode: 974, Total Steps: 247422, Ep Step: 102, Raw Reward: 110.64, Epsilon: 0.05
# Episode: 975, Total Steps: 247609, Ep Step: 187, Raw Reward: 145.10, Epsilon: 0.05
# Episode: 976, Total Steps: 247795, Ep Step: 186, Raw Reward: 155.86, Epsilon: 0.05
# Episode: 977, Total Steps: 247892, Ep Step: 97, Raw Reward: 90.13, Epsilon: 0.05
# Episode: 978, Total Steps: 248022, Ep Step: 130, Raw Reward: 283.56, Epsilon: 0.05
# Episode: 979, Total Steps: 248195, Ep Step: 173, Raw Reward: 40.40, Epsilon: 0.05
# Episode: 980, Total Steps: 248364, Ep Step: 169, Raw Reward: 42.90, Epsilon: 0.05
# Episode: 981, Total Steps: 248537, Ep Step: 173, Raw Reward: 45.42, Epsilon: 0.05
# Episode: 982, Total Steps: 248718, Ep Step: 181, Raw Reward: 149.45, Epsilon: 0.05
# Episode: 983, Total Steps: 248904, Ep Step: 186, Raw Reward: 181.04, Epsilon: 0.05
# Episode: 984, Total Steps: 249067, Ep Step: 163, Raw Reward: 41.47, Epsilon: 0.05
# Episode: 985, Total Steps: 249169, Ep Step: 102, Raw Reward: 122.80, Epsilon: 0.05
# Episode: 986, Total Steps: 249331, Ep Step: 162, Raw Reward: 37.65, Epsilon: 0.05
# Episode: 987, Total Steps: 249536, Ep Step: 205, Raw Reward: 327.09, Epsilon: 0.05
# Episode: 988, Total Steps: 249702, Ep Step: 166, Raw Reward: 32.54, Epsilon: 0.05
# Episode: 989, Total Steps: 249863, Ep Step: 161, Raw Reward: 35.92, Epsilon: 0.05
# Episode: 990, Total Steps: 250032, Ep Step: 169, Raw Reward: 45.36, Epsilon: 0.05
# Episode: 991, Total Steps: 250235, Ep Step: 203, Raw Reward: 304.21, Epsilon: 0.05
# Episode: 992, Total Steps: 250410, Ep Step: 175, Raw Reward: 49.83, Epsilon: 0.05
# Episode: 993, Total Steps: 250582, Ep Step: 172, Raw Reward: 50.93, Epsilon: 0.05
# Episode: 994, Total Steps: 250762, Ep Step: 180, Raw Reward: 169.30, Epsilon: 0.05
# Episode: 995, Total Steps: 250925, Ep Step: 163, Raw Reward: 42.33, Epsilon: 0.05
# Episode: 996, Total Steps: 251024, Ep Step: 99, Raw Reward: 111.36, Epsilon: 0.05
# Episode: 997, Total Steps: 251189, Ep Step: 165, Raw Reward: 30.72, Epsilon: 0.05
# Episode: 998, Total Steps: 251355, Ep Step: 166, Raw Reward: 47.34, Epsilon: 0.05
# Episode: 999, Total Steps: 251531, Ep Step: 176, Raw Reward: 50.67, Epsilon: 0.05
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 251698, Ep Step: 167, Raw Reward: 29.34, Epsilon: 0.05
